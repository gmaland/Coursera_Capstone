# %% [markdown]
# ### NOTE:  In order to create a single Python file to submit, I needed to concatenate 7 files.  This is why you will see repeated sections and imports.  I also have a number of lines commented out.  This is because in my workflow, I had already updated the data in various ways and then saved it to a pickle file. So, the flow is that each file creates pickle files which are then picked up by the next python file to resume processing.  I left in the comments to show what I needed to do at various points in the process.

# %% [markdown]
# ### Do the basic imports

# %%
# !pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in d:\applications\anaconda\lib\site-packages (4.9.3)
# Requirement already satisfied: soupsieve>1.2; python_version >= "3.0" in d:\applications\anaconda\lib\site-packages (from beautifulsoup4) (2.0.1)

# %%
import pandas as pd
import numpy as np

# %%
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# ### Load the BeautifulSoup object with Wiki data and replace line breaks for easier parsing

# %%
wiki_url = "https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M"

page = requests.get(wiki_url).text
soup = BeautifulSoup(page, "html.parser")

# REPLACE <BR> WITH PIPE FOR PARSING
delimiter = '|'                           # unambiguous string
for line_break in soup.findAll('br'):       # loop through line break tags
    line_break.replaceWith(delimiter)

# %% [markdown]
# ### Create a function to clean the neighborhood data

# %%
def special_replace(neigh):
    result = neigh.replace('(','')
    result = result.replace(')','')
    result = result.strip()
    return result

# %% [markdown]
# ### Create a dataframe to hold data. Parse out the data, omitting cases where no borough is listed. Sort the dataframe by borough and postal code.

# %%
data = {"PostalCode":"XXX", "Borough":"XXX", "Neighborhood":"XXX"}
tor_neigh = pd.DataFrame(columns=["PostalCode","Borough","Neighborhood"], index = [0]) 
neigh = ""

tbl = soup.find_all('table')[0]

use_anchor_method = False
row_marker = 0

# Big Parsing Loop - Rows, then Cells
for row in tbl.find_all('tr'):
    column_marker = 0
    columns = row.find_all('td')
    # each td has a p with the postal code, a span which can say Not assigned, or a span with <a> elements,
    # the first is the borough, all the rest of the items after split are the neighborhoods
    for column in columns:
        code = column.find_all('p')[0].get_text()[:3]
        span = column.find_all('span')[0]
        a_count = len(span.find_all('a')) 
        if span.get_text() == "Not assigned":
            continue
        else: 
            special_neighs = span.get_text().replace('/','|').split('|')
            borough = special_neighs[0]
            for n in range(1, len(special_neighs)):
                newneigh = special_neighs[n]
                if neigh == np.nan or neigh == None or neigh == "":
                    neigh = special_replace(newneigh)
                else:
                    neigh += ", " + special_replace(newneigh)
                        
            new_row = {'PostalCode':code,'Borough':borough,'Neighborhood':neigh}
            tor_neigh = tor_neigh.append(new_row, ignore_index=True)
        
        # Clear these values so we can't contaminate the next pass
        borough = ""
        neigh = ""
        newneigh = ""
        column_marker += 1

tor_neigh.drop(labels=0,axis=0,inplace=True)
tor_neigh.sort_values(by=["Borough", "PostalCode"], inplace=True)
tor_neigh = tor_neigh.reset_index(drop=True)
tor_neigh[1:51]
# Out:
#    PostalCode           Borough  \
# 1         M4P   Central Toronto
# 2         M4R   Central Toronto
# 3         M4S   Central Toronto
# 4         M4T   Central Toronto
# 5         M4V   Central Toronto
# 6         M5N   Central Toronto
# 7         M5P   Central Toronto
# 8         M5R   Central Toronto
# 9         M4W  Downtown Toronto
# 10        M4X  Downtown Toronto
# 11        M4Y  Downtown Toronto
# 12        M5A  Downtown Toronto
# 13        M5B  Downtown Toronto
# 14        M5C  Downtown Toronto
# 15        M5E  Downtown Toronto
# 16        M5G  Downtown Toronto
# 17        M5H  Downtown Toronto
# 18        M5J  Downtown Toronto
# 19        M5K  Downtown Toronto
# 20        M5L  Downtown Toronto
# 21        M5S  Downtown Toronto
# 22        M5T  Downtown Toronto
# 23        M5V  Downtown Toronto
# 24        M5W  Downtown Toronto
# 25        M5X  Downtown Toronto
# 26        M6G  Downtown Toronto
# 27        M4E      East Toronto
# 28        M4K      East Toronto
# 29        M4L      East Toronto
# 30        M4M      East Toronto
# 31        M7Y      East Toronto
# 32        M4B         East York
# 33        M4C         East York
# 34        M4G         East York
# 35        M4H         East York
# 36        M4J         East York
# 37        M8V         Etobicoke
# 38        M8W         Etobicoke
# 39        M8X         Etobicoke
# 40        M8Y         Etobicoke
# 41        M8Z         Etobicoke
# 42        M9A         Etobicoke
# 43        M9B         Etobicoke
# 44        M9C         Etobicoke
# 45        M9P         Etobicoke
# 46        M9R         Etobicoke
# 47        M9V         Etobicoke
# 48        M9W         Etobicoke
# 49        M7R       Mississauga
# 50        M2H        North York
#
#                                          Neighborhood
# 1                                    Davisville North
# 2                                  North Toronto West
# 3                                          Davisville
# 4                         Moore Park, Summerhill East
# 5   Summerhill West, Rathnelly, South Hill, Forest...
# 6                                            Roselawn
# 7                            Forest Hill North & West
# 8                 The Annex, North Midtown, Yorkville
# 9                                            Rosedale
# 10                        St. James Town, Cabbagetown
# 11                               Church and Wellesley
# 12                          Regent Park, Harbourfront
# 13                           Garden District, Ryerson
# 14                                     St. James Town
# 15                                        Berczy Park
# 16                                 Central Bay Street
# 17                           Richmond, Adelaide, King
# 18  Harbourfront East, Union Station, Toronto Islands
# 19           Toronto Dominion Centre, Design Exchange
# 20                     Commerce Court, Victoria Hotel
# 21                     University of Toronto, Harbord
# 22          Kensington Market, Chinatown, Grange Park
# 23  CN Tower, King and Spadina, Railway Lands, Har...
# 24   Stn A PO Boxes, 25 The Esplanade, Enclave of M5E
# 25             First Canadian Place, Underground city
# 26                                           Christie
# 27                                        The Beaches
# 28                       The Danforth West, Riverdale
# 29                     India Bazaar, The Beaches West
# 30                                    Studio District
# 31  Business reply mail Processing Centre, 969 Eas...
# 32                    Parkview Hill, Woodbine Gardens
# 33                                   Woodbine Heights
# 34                                            Leaside
# 35                                   Thorncliffe Park
# 36                   East Toronto, The Danforth, East
# 37       New Toronto, Mimico South, Humber Bay Shores
# 38                             Alderwood, Long Branch
# 39      The Kingsway, Montgomery Road, Old Mill North
# 40  Old Mill South, King's Mill Park, Sunnylea, Hu...
# 41  Mimico NW, The Queensway West, South of Bloor,...
# 42                                   Islington Avenue
# 43  West Deane Park, Princess Gardens, Martin Grov...
# 44  Eringate, Bloordale Gardens, Old Burnhamthorpe...
# 45                                          Westmount
# 46  Kingsview Village, St. Phillips, Martin Grove ...
# 47  South Steeles, Silverstone, Humbergate, Jamest...
# 48  Northwest, Clairville, Humberwood, Woodbine Do...
# 49  Canada Post Gateway Processing Centre, Enclave...
# 50                                  Hillcrest Village

# %%
tor_neigh.shape
# Out:
# (103, 3)

# %% [markdown]
# <div>
# <b>I DID NOT FIND THIS TO BE TRUE</b><br>
# More than one neighborhood can exist in one postal code area. For example, in the table on the Wikipedia page,
# you will notice that M5A is listed twice and has two neighborhoods: Harbourfront and Regent Park.
# These two rows will be combined into one row with the neighborhoods separated with a comma as shown in row 11
# in the above table.
# </div>

# %%
df_pc_count = tor_neigh.groupby('PostalCode').size().reset_index()
df_pc_count.columns = ["PostalCode","CodeCount"]
df_pc_count[df_pc_count["CodeCount"] > 1]
# Out:
# Empty DataFrame
# Columns: [PostalCode, CodeCount]
# Index: []

# %%
tor_neigh[tor_neigh["PostalCode"]=="M5A"]

# %%
tor_neigh.tail()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3eaa9b8d5988> in <module>
# ----> 1 tor_neigh.tail()
#
# NameError: name 'tor_neigh' is not defined

# %% [markdown]
# ### Save the dataframe for use in another file

# %%
tor_neigh.to_pickle('toronto_neighborhoods_step_1_V2.pkl')

# %% [markdown]
# ### Import libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Load data from files. We saved the toronto neighborhoods in the first step of this project.

# %%
tor_neigh = pd.read_pickle('toronto_neighborhoods_step_1_V2.pkl')
loglatdata = pd.read_csv('Geospatial_Coordinates.csv')

# %%
loglatdata.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %% [markdown]
# ### Merge the data together

# %%
tor_longlat = tor_neigh.merge(loglatdata,how="left",left_on=["PostalCode"],right_on=["Postal Code"])

# %% [markdown]
# ### Drop the redundant column

# %%
tor_longlat.drop(columns=['Postal Code'], axis=1)
# Out:
#     PostalCode          Borough  \
# 0          M4N  Central Toronto
# 1          M4P  Central Toronto
# 2          M4R  Central Toronto
# 3          M4S  Central Toronto
# 4          M4T  Central Toronto
# ..         ...              ...
# 98         M6C             York
# 99         M6E             York
# 100        M6M             York
# 101        M6N             York
# 102        M9N             York
#
#                                          Neighborhood   Latitude  Longitude
# 0                                       Lawrence Park  43.728020 -79.388790
# 1                                    Davisville North  43.712751 -79.390197
# 2                                  North Toronto West  43.715383 -79.405678
# 3                                          Davisville  43.704324 -79.388790
# 4                         Moore Park, Summerhill East  43.689574 -79.383160
# ..                                                ...        ...        ...
# 98                                 Humewood-Cedarvale  43.693781 -79.428191
# 99                                Caledonia-Fairbanks  43.689026 -79.453512
# 100  Del Ray, Mount Dennis, Keelsdale and Silverthorn  43.691116 -79.476013
# 101                     Runnymede, The Junction North  43.673185 -79.487262
# 102                                            Weston  43.706876 -79.518188
#
# [103 rows x 5 columns]

# %% [markdown]
# ### Do we need to remove any data?

# %%
tor_longlat.isnull().values.any()
# Out:
# False

# %%
tor_longlat.head()
# Out:
#   PostalCode          Borough                 Neighborhood Postal Code  \
# 0        M4N  Central Toronto                Lawrence Park         M4N
# 1        M4P  Central Toronto             Davisville North         M4P
# 2        M4R  Central Toronto           North Toronto West         M4R
# 3        M4S  Central Toronto                   Davisville         M4S
# 4        M4T  Central Toronto  Moore Park, Summerhill East         M4T
#
#     Latitude  Longitude
# 0  43.728020 -79.388790
# 1  43.712751 -79.390197
# 2  43.715383 -79.405678
# 3  43.704324 -79.388790
# 4  43.689574 -79.383160

# %%
tor_longlat.to_pickle('tor_longlat_data.pkl')

# %% [markdown]
# ### Doing all my imports

# %%
import pandas as pd
import numpy as np

# %%
import requests

# %%
from sklearn.cluster import KMeans

# %%
# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# %%
#!conda install -c conda-forge geopy
# !pip install geopy
# Out:
# Requirement already satisfied: geopy in d:\applications\anaconda\lib\site-packages (2.2.0)
# Requirement already satisfied: geographiclib<2,>=1.49 in d:\applications\anaconda\lib\site-packages (from geopy) (1.52)

# %%
from geopy.geocoders import Nominatim

# %%
#!conda install -c conda-forge folium=0.5.0 --yes
# !pip install folium
import folium # map rendering library
# Out:
# Requirement already satisfied: folium in d:\applications\anaconda\lib\site-packages (0.12.1)
# Requirement already satisfied: requests in d:\applications\anaconda\lib\site-packages (from folium) (2.24.0)
# Requirement already satisfied: numpy in d:\applications\anaconda\lib\site-packages (from folium) (1.19.2)
# Requirement already satisfied: branca>=0.3.0 in d:\applications\anaconda\lib\site-packages (from folium) (0.4.2)
# Requirement already satisfied: jinja2>=2.9 in d:\applications\anaconda\lib\site-packages (from folium) (2.11.2)
# Requirement already satisfied: idna<3,>=2.5 in d:\applications\anaconda\lib\site-packages (from requests->folium) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in d:\applications\anaconda\lib\site-packages (from requests->folium) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in d:\applications\anaconda\lib\site-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in d:\applications\anaconda\lib\site-packages (from requests->folium) (1.25.11)
# Requirement already satisfied: MarkupSafe>=0.23 in d:\applications\anaconda\lib\site-packages (from jinja2>=2.9->folium) (1.1.1)

# %% [markdown]
# ### Get saved Toronto data

# %%
tor_longlat = pd.read_pickle('tor_longlat_data.pkl')

# %% [markdown]
# ### Create map of Toronto neighborhoods

# %%
ave_long = tor_longlat["Longitude"].mean()
ave_lat = tor_longlat["Latitude"].mean()

# %% [markdown]
# ### Map of neigborhoods

# %%
map_toronto = folium.Map(location=[ave_lat, ave_long], zoom_start=12)

# add markers to map
for lat, lng, borough, neighborhood in zip(tor_longlat['Latitude'], tor_longlat['Longitude'], tor_longlat['Borough'], tor_longlat['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_946a476d2cd84461bbff632b8e228d03%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_946a476d2cd84461bbff632b8e228d03%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_946a476d2cd84461bbff632b8e228d03%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_946a476d2cd84461bbff632b8e228d03%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B43.70460773398059%2C%20-79.39715291165048%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %% [markdown]
# ### Foursquare credentials - MODIFIED - FOR PRIVACY

# %%
CLIENT_ID = 'BOIJJKYCZMDIUBCUSMDOXANZCVNFNKWTNS3KJZXEB4PL9999' # your Foursquare ID
CLIENT_SECRET = '5EJRIL4HGEV0XWVIORAKGQV225IKNKGLULRAKZGPVHB49999' # your Foursquare Secret
VERSION = '20210715' # Foursquare API version
LIMIT = 100 # A default Foursquare API limit value

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: BOIJJKYCZMDIUBCUSMDOXANZCVNFNKWTNS3KJZXEB4PLHQHI
# CLIENT_SECRET:5EJRIL4HGEV0XWVIORAKGQV225IKNKGLULRAKZGPVHB4RXS0

# %% [markdown]
# ### Method to extract data from Explore endpoint

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        # print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['id'], # GM - I need this Id so I can get details (premium call)
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue_Id',
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
# This is my dataframe for gathering detailed venue data
venue_details = pd.DataFrame(columns = ["Venue_Id",
                        "Name",
                        "CheckinsCount",
                        "UsersCount",
                        "TipsCount",
                        "VisitsCount",
                        "LikesCount",
                        "Rating",
                        "PriceTier"])

# %% [markdown]
# ### Method to extract data from Venues Premium Endpoint

# %%
def getVenueDetails(venue_id):
   
    url = 'https://api.foursquare.com/v2/venues/{}?&client_id={}&client_secret={}&v={}'.format(
            venue_id,
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION
            )
    
    # make the GET request
    result = requests.get(url).json()["response"]['venue']
    
    stats = result["stats"]
    pricetier = np.nan
    checkinsCount = np.nan
    usersCount = np.nan
    tipCount = np.nan
    visitsCount = np.nan
    
    if "price" in result:
        price = result["price"]
        if "tier" in price:
            pricetier = price["tier"]
    
    if "checkinsCount" in stats:
        checkinsCount = stats["checkinsCount"]
    if "usersCount" in stats:
        usersCount = stats["usersCount"]
    if "tipCount" in stats:
        tipCount = stats["tipCount"]
    else:
        tipCount = 0
    if "visitsCount" in stats:
        visitsCount = stats["visitsCount"]

        
    venue_details.loc[len(venue_details.index)] = [result["id"],
                                                  result["name"],
                                                  checkinsCount,
                                                  usersCount,
                                                  tipCount,
                                                  visitsCount,
                                                  result["likes"]["count"],
                                                  result["rating"],
                                                  pricetier]

# %%
getVenueDetails('4ad69511f964a520e40721e3')
venue_details.head(10)
# Out:
#                    Venue_Id                                    Name  \
# 0  4ad69511f964a520e40721e3  The Keg Steakhouse + Bar - York Street
#
#    CheckinsCount  UsersCount TipsCount  VisitsCount LikesCount  Rating  \
# 0            NaN         NaN        79          NaN        269     8.7
#
#   PriceTier
# 0         2

# %%
# DO NOT RUN THIS CODE CASUALLY - YOU CAN LOSE DATA!
# venue_details.to_pickle("venue_details.pkl")

# %%
getVenueDetails('4ae6ea6ef964a52082a721e3')
venue_details.head()

# %%
names = tor_longlat["Neighborhood"]
longitude = tor_longlat["Longitude"]
latitude = tor_longlat["Latitude"]
toronto_venues = getNearbyVenues(names, latitude, longitude)
toronto_venues.head()

# %% [markdown]
# <H1>Save Toronto Venues Data</H1>

# %%
# DO NOT RUN THIS CODE CASUALLY - YOU CAN LOSE DATA!
# toronto_venues.to_pickle("toronto_venues_data.pkl")

# %%
# I want to see some really popular places to test the details results
toronto_popular = toronto_venues[(toronto_venues["Neighborhood"] == "Commerce Court, Victoria Hotel") & (toronto_venues["Venue Category"].str.contains("Restaurant"))]
toronto_popular.head()

# %% [markdown]
# ### I believe there were <b>way too many venue categories</b> in the FourSquare data, so I manually created a much simplified set of 10 categories which I want to cluster on.

# %%
simple_categories = pd.read_csv('FourSquare Fun Categories - V5.csv')
simple_categories.head()

# %% [markdown]
# ### Method to determine if a venue is Fun

# %%
fun_places = ['Entertainment','Recreation','CheapMeal','CoffeeDessert','Ethnic Food','Fancy Food','Bar','FunStore']

def get_simple_category(venue_type):
    #print(venue_type)
    venue_type = str.strip(venue_type)
    column_name = [col for col in simple_categories.columns if (simple_categories[col] == venue_type).any()]
    if len(column_name) == 0:
        result="NOT FOUND"
        print("NOT FOUND: " + venue_type)
    elif column_name[0] in fun_places:
        result = column_name[0]
    else:
        result="NOT FUN!"
    return result

# %% [markdown]
# ### Assign the simple categories to the main venues dataframe

# %%
toronto_venues["SimpleCategory"] = toronto_venues["Venue Category"].apply(get_simple_category)
toronto_venues.head()

# %%
toronto_venues.to_pickle("toronto_venues_fun.pkl")

# %%
# Remove all the venues that are not fun
toronto_venues_fun = toronto_venues[toronto_venues["SimpleCategory"] != "NOT FUN!"]
toronto_venues_fun.to_pickle("toronto_venues_fun.pkl")

# %% [markdown]
# ### One hot encoding

# %%
# toronto_onehot = pd.get_dummies(toronto_venues[['Venue Category']], prefix="", prefix_sep="")
toronto_onehot = pd.get_dummies(toronto_venues_fun[['SimpleCategory']], prefix="", prefix_sep="")
# add neighborhood column back to dataframe
toronto_onehot['Neighborhood'] = toronto_venues_fun['Neighborhood'] 

# move neighborhood column to the first column
fixed_columns = [toronto_onehot.columns[-1]] + list(toronto_onehot.columns[:-1])
toronto_onehot = toronto_onehot[fixed_columns]

toronto_onehot.head()

# %%
#toronto_onehot = toronto_onehot.drop(['NOT FOUND','NOT FUN!'],axis=1)
toronto_onehot = toronto_onehot.drop(['NOT FUN!'],axis=1)

# %%
toronto_onehot = toronto_onehot.drop(['NOT FOUND'],axis=1)

# %% [markdown]
# ### Getting Neighborhoods with the Most Fun Venues

# %%
toronto_sum = toronto_onehot.groupby('Neighborhood').sum().reset_index()
#df.sum(axis=1)
toronto_sum["TotalFun"] = toronto_sum.sum(axis=1)
#df.sort_values(by=['c1'])
toronto_sum = toronto_sum.sort_values(by=["TotalFun"],ascending=False).reset_index()
toronto_sum.head(10)

# %%
# DO NOT RUN THIS CODE CASUALLY - YOU CAN LOSE DATA!
# toronto_sum.to_pickle("toronto_most_fun.pkl")

# %% [markdown]
# <h1>----------End of Initial Toronto Fun Data----------</h1>

# %% [markdown]
# <h1>--------Getting New York Data--------</h1>

# %%
ny_long_lat = pd.read_pickle("nyc_long_lat.pkl")

# %%
ny_long_lat.head()

# %%
names = ny_long_lat["Neighborhood"]
longitude = ny_long_lat["Longitude"]
latitude = ny_long_lat["Latitude"]
nyc_venues = getNearbyVenues(names, latitude, longitude)
nyc_venues.head()

# %%
nyc_venues["SimpleCategory"] = nyc_venues["Venue Category"].apply(get_simple_category)
nyc_venues.head()

# %%
nyc_venues[nyc_venues["Venue Category"].str.contains("Hotel")][0:50]

# %%
nyc_venues.head()

# %%
# Remove all not found and not fun - not found categories are all not fun - I checked
nyc_venues = nyc_venues[ (nyc_venues['SimpleCategory']!='NOT FOUND') | (nyc_venues['SimpleCategory']!='NOT FUN!') ]

# %% [markdown]
# ### TO PREVENT ERRORS, I OFTEN NEED TO COMMENT OUT THIS CODE

# %%
# Save all the nyc venues data which is fun

# DO NOT RUN THIS CODE CASUALLY - YOU CAN LOSE DATA!
# nyc_venues.to_pickle("nyc venues only fun.pkl")

# %%
# get names of indexes for which
# column Age has value 21
#index_names = nyc_venues[ nyc_venues['SimpleCategory'] == 'NOT FOUND' ].index
  
# drop these row indexes
# from dataFrame
#nyc_venues.drop(index_names, inplace = True)

# %%
# one hot encoding
nyc_onehot = pd.get_dummies(nyc_venues[['SimpleCategory']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
nyc_onehot['Neighborhood'] = nyc_venues['Neighborhood'] 

# move neighborhood column to the first column
fixed_columns = [nyc_onehot.columns[-1]] + list(nyc_onehot.columns[:-1])
nyc_onehot = nyc_onehot[fixed_columns]

nyc_onehot.head()
#nyc_onehot = nyc_onehot.drop(['NOT FUN!'],axis=1)
nyc_sum = nyc_onehot.groupby('Neighborhood').sum().reset_index()
nyc_sum["TotalFun"] = nyc_sum.sum(axis=1)
nyc_sum = nyc_sum.sort_values(by=["TotalFun"],ascending=False).reset_index()

# Save all the fun data for nyc

# DO NOT RUN THIS CODE CASUALLY - YOU CAN LOSE DATA!
# nyc_sum.to_pickle("nyc_most_fun.pkl")

nyc_sum.head(30)

# %% [markdown]
# <h1>Fun Popular Focus Idea</h1>
# <p>
# I'm thinking I will take the top 20 neighborhoods based on the Fun Total for both Toronto and NYC
# Then I will take all the fun places in those neighborhoods and get data for number of reviews and total score.
# Then I will come up with a formula which assigns a fun weighting to each simple category and then does a calculation involving the number of reviews and the total score - and then I will aggregate these back together and get a total fun result.
# </p>

# %%
toronto_grouped = toronto_onehot.groupby('Neighborhood').mean().reset_index()
toronto_grouped.head(30)

# %%
num_top_venues = 5

for hood in toronto_grouped['Neighborhood']:
    print("----"+hood+"----")
    # T - Transpose index and columns. Reflect the DataFrame over its main diagonal by writing rows as columns and vice-versa. The property T is an accessor to the method
    temp = toronto_grouped[toronto_grouped['Neighborhood'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %% [markdown]
# <div>
# <b>NOTE TO PEER REVIEWER: THIS WILL LOOK MUCH DIFFERENT BECAUSE I AM USING MY OWN LIST OF SIMPLIFIED VENUE CATEGORIES. I BELIEVE THIS IS A SUBSTANTIAL IMPROVEMENT FOR CLUSTERING.</b>
# </div>

# %%
# create map
map_clusters = folium.Map(location=[ave_lat, ave_long], zoom_start=11)

# Cluster Names
cluster_types = ['Stores, Recreation, Food','Cheap food, ethnic restaurants','Recreation, Travel, Stores','Ethnic Food, Coffee, Dessert Places', 'Recreation, Travel, Miscellaneous']

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(toronto_merged['Latitude'], toronto_merged['Longitude'], toronto_merged['Neighborhood'], toronto_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + cluster_types[cluster], parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_ca2cd55fe3ba441c8bc06b5c0e70dd57%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_ca2cd55fe3ba441c8bc06b5c0e70dd57%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_ca2cd55fe3ba441c8bc06b5c0e70dd57%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_ca2cd55fe3ba441c8bc06b5c0e70dd57%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B43.70460773398059%2C%20-79.39715291165048%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %% [markdown]
# <h1>This is really about getting the data together, step 2</h1>

# %%
import requests
import pandas as pd
import numpy as np

# %%
CLIENT_ID = 'BOIJJKYCZMDIUBCUSMDOXANZCVNFNKWTNS3KJZXEB4PLHQHI' # your Foursquare ID
CLIENT_SECRET = '5EJRIL4HGEV0XWVIORAKGQV225IKNKGLULRAKZGPVHB4RXS0' # your Foursquare Secret
VERSION = '20210715' # Foursquare API version
LIMIT = 100 # A default Foursquare API limit value

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: BOIJJKYCZMDIUBCUSMDOXANZCVNFNKWTNS3KJZXEB4PLHQHI
# CLIENT_SECRET:5EJRIL4HGEV0XWVIORAKGQV225IKNKGLULRAKZGPVHB4RXS0

# %%
# Get rid of checkins users and vists
# toronto_onehot = toronto_onehot.drop(['NOT FOUND'],axis=1)
#venue_details = venue_details.drop(['CheckinsCount', 'UsersCount', 'VisitsCount'], axis=1)
#venue_details.to_pickle("venue_details.pkl")

# %%
# I need to keep adding details to my pickle file and then remember to save again when I'm done
# BE CAREFUL!! tHIS IS READING NOT WRITING!!!!
# venue_details = pd.read_pickle("venue_details.pkl")

# %%
venue_details.to_csv("venue_details.csv")

# %%
# This is my dataframe for gathering detailed venue data
# venue_details = pd.DataFrame(columns = ["Venue_Id",
#                        "Name",
#                        "TipsCount",
#                        "LikesCount",
#                        "Rating",
#                        "RatingSignals",
#                        "PriceTier"])

# %%
venue_details.to_pickle("venue_details.pkl")

# %%
def getVenueDetails(venue_id):
    # Don't run this again if we already have the data, since these are premium calls
    
    if(venue_details['Venue_Id'] == venue_id).any():
        return "WASTE" 
    
    url = 'https://api.foursquare.com/v2/venues/{}?&client_id={}&client_secret={}&v={}'.format(
            venue_id,
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION
            )
    
    # make the GET request
    result = requests.get(url).json()
    
    if "meta" in result:
        if "errorType" in result["meta"]:
            errorMessage = result["meta"]["errorType"]
            # print("VENUE_ID: " + venue_id + " - WE GOT THIS ERROR MESSAGE: " + errorMessage)
            return "QUOTA"
    else:
        print("meta not in result")
        
    try:
        result = result["response"]['venue']
    except Exception:
        print("Non-Excessive Requests Exception with venue_id: " + venue_id + " - REMOVE VENUE")
        return "ERROR"
    
    stats = result["stats"]
    pricetier = 0
    rating = 0
    ratingSignals = 0
    tipCount = 0
    
    # add ratingSignals
    if "price" in result:
        price = result["price"]
        if "tier" in price:
            pricetier = price["tier"]
    if "tipCount" in stats:
        tipCount = stats["tipCount"]
    if "rating" in result:
        rating = result["rating"]
    if "ratingSignals" in result:
        ratingSignals = result["ratingSignals"]

        
    venue_details.loc[len(venue_details.index)] = [result["id"],
                                                  result["name"],
                                                  tipCount,
                                                  result["likes"]["count"],
                                                  rating,
                                                  ratingSignals,
                                                  pricetier,
                                                  tipCount + (result["likes"]["count"] * 2) + ratingSignals]
    return "SUCCESS"

# %%
# I want a number which helps show how popular and fun a place is - giving x2 for LIKES
# df['DataFrame Column'] = df['DataFrame Column'].fillna(0)
#venue_details["TipsCount"] = venue_details["TipsCount"].fillna(0);
#venue_details["LikesCount"] = venue_details["LikesCount"].fillna(0);
#venue_details["RatingSignals"] = venue_details["RatingSignals"].fillna(0);

# %%
#venue_details["VoteSum"] = (venue_details["TipsCount"]) + (venue_details["LikesCount"] * 2) + (venue_details["RatingSignals"])

# %%
#venue_details.sort_values(by="VoteSum", ascending=False)[0:60]

# %%
# Restore a bunch of dataframes

# All the toronto venues
toronto_venues = pd.read_pickle("toronto_venues_data.pkl")
# Only the fun toronto venues
toronto_venues_fun = pd.read_pickle("toronto_venues_fun.pkl")
# Shows the total fun score across neighborhoods
toronto_sum = pd.read_pickle("toronto_most_fun.pkl")
# For NYC, I only have the fun for now
nyc_venues_fun = pd.read_pickle("nyc venues only fun.pkl")
# For NYC, total fun scores across neighborhoods
nyc_sum= pd.read_pickle("nyc_most_fun.pkl")

# %%
# Populate venue data by looping through most popular neighborhoods in order of popularity
def loadVenueData(aggdataframe, venuedataframe):
    detailcounter = 0

    for index, row in aggdataframe[0:10].iterrows():
        print("Index: " + str(index))
        neighborhood = aggdataframe.iloc[index]["Neighborhood"]
        print(neighborhood)
        print('------------------------------------------')
        
        for index, row in venuedataframe[venuedataframe["Neighborhood"] == neighborhood].iterrows():
            if detailcounter > 500:
                print("WE HAVE REACHED OUR GOAL")
                return

            # Maybe this iloc approach was wrong!!!
            #venue_id = venuedataframe.iloc[index]["Venue_Id"]
            #neighborhood = venuedataframe.iloc[index]["Neighborhood"]
            #print(venue_id + ", " + neighborhood)
            venue_id = row["Venue_Id"]
            neighborhood = row["Neighborhood"]
            #print(venue_id + ", " + neighborhood)
            
            detailSuccess = getVenueDetails(venue_id)
            # WASTE, QUOTA, ERROR, SUCCESS
            
            if(detailSuccess == "SUCCESS"):
                print(str(detailcounter) + ': ' + venue_id)
                # For now, I am limiting tries even if nothing works - PUT THIS BACK UNDER SUCCESS
                detailcounter +=1
                
            elif detailSuccess == "QUOTA":
                print("WE HAVE REACHED OUR QUOTA")
                return

# %%
loadVenueData(toronto_sum, toronto_venues_fun)
#loadVenueData(nyc_sum, nyc_venues_fun)
# Out:
# Index: 0
# First Canadian Place, Underground city
# ------------------------------------------
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# 0: 50468014e4b01c18bb731df8
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# 1: 4e048b98315168be7fd7ee4d
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# 2: 5a5a59c5a423620ec1dafd41
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# 3: 5321f4d9e4b07946702e6e08
# 4: 4b8702fdf964a52055ab31e3
# Would be a wasted API call
# Would be a wasted API call
# 5: 509bb871e4b09c7ac93f6642
# 6: 4ad4c062f964a520bbf720e3
# 7: 4afa1f33f964a520e91622e3
# 8: 4ad4c062f964a520baf720e3
# 9: 5057b3d1e4b0e54029a4acc8
# Would be a wasted API call
# 10: 55a63131498e114c3c6d2cd5
# Would be a wasted API call
# 11: 4b8d5856f964a520f4f532e3
# Would be a wasted API call
# 12: 4b50d070f964a5206d3327e3
# Would be a wasted API call
# Would be a wasted API call
# 13: 5b1a76586f0aa2002c5d9a0c
# 14: 4b461f97f964a5202e1726e3
# Would be a wasted API call
# 15: 4c3c73137ea89521dc322247
# 16: 4adc5c6af964a520da2b21e3
# 17: 5227fd9d7e48b6c9c707f4fa
# 18: 52ec621e498ec68fa15ee922
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Index: 1
# Commerce Court, Victoria Hotel
# ------------------------------------------
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Index: 2
# Harbourfront East, Union Station, Toronto Islands
# ------------------------------------------
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# 19: 4b7199ebf964a52048502de3
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# 20: 4ad4c05ef964a520cbf620e3
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# 21: 4e0f9e9e1838f62321d17b8d
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# 22: 5952cf02829b0c59fa430f63
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# 23: 5671974c498e35b7bd0517a4
# Would be a wasted API call
# Would be a wasted API call
# 24: 5a23467c47f8762eb7bdfc90
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# 25: 4e4fe00cc65bb313ba8bd2a8
# 26: 598859002632ec78a08edcc8
# Would be a wasted API call
# 27: 59a0c566fc9e941199511d9f
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# 28: 4db81aaa43a1a75c1f6afa6b
# Index: 3
# Toronto Dominion Centre, Design Exchange
# ------------------------------------------
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# 29: 4bacf405f964a520881d3be3
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# 30: 5321ff4f498e273e359a05e0
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# 31: 4db5e84443a1369cb5da528a
# Would be a wasted API call
# Would be a wasted API call
# Index: 4
# Stn A PO Boxes, 25 The Esplanade, Enclave of M5E
# ------------------------------------------
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# 32: 4ad4c05ef964a520a9f620e3
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# 33: 5553954a498e8e11bc49ecf2
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# 34: 4ad4c062f964a520d9f720e3
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# 35: 4b689994f964a52030822be3
# Index: 5
# Richmond, Adelaide, King
# ------------------------------------------
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# 36: 5c9d602f25fb7b002c79b669
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# 37: 529612de11d2ab526191ccc9
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# 38: 59f784dd28122f14f9d5d63d
# 39: 5c9aaa3f66f3cd002c95bd58
# Would be a wasted API call
# 40: 537773d1498e74a75bb75c1e
# 41: 5548cfb6498ec3e4bdfde59a
# Would be a wasted API call
# Would be a wasted API call
# 42: 4ae60299f964a52003a421e3
# Would be a wasted API call
# Would be a wasted API call
# 43: 505125b2e4b0253ca4e47351
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# 44: 4ad4c061f964a520a9f720e3
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# 45: 4ad4c05ef964a520e2f620e3
# Would be a wasted API call
# Would be a wasted API call
# 46: 50885719498ea7b5aab3a74c
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# 47: 4ee117150cd686aafce847f4
# Would be a wasted API call
# 48: 549dd93f498eec33464a5fd2
# 49: 54360d40498ebb616b99a257
# Would be a wasted API call
# 50: 4ac4e289f964a520699f20e3
# Would be a wasted API call
# Would be a wasted API call
# 51: 5b036379bed483002cd68ac6
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Index: 6
# Garden District, Ryerson
# ------------------------------------------
# 52: 5615b6c4498e3c32c67ad78f
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# 53: 5064c3dde4b07c5a18986283
# Would be a wasted API call
# Would be a wasted API call
# 54: 509e9ef6e4b0ab175389a6c5
# Would be a wasted API call
# Would be a wasted API call
# 55: 4adbbae6f964a520402a21e3
# 56: 4ad4c061f964a52095f720e3
# 57: 4adc9148f964a520512d21e3
# 58: 4b32a8bdf964a5202d1125e3
# 59: 4fe4a773e4b0ef61f5212ecd
# 60: 4ad77a12f964a520260b21e3
# 61: 5a55078bda5ede6ed9d73a62
# 62: 4cd2e74d3e0c8cfa87971a12
# 63: 502ad662e4b0cc2719059805
# 64: 4ad4c064f964a5208ff820e3
# 65: 4b2bd898f964a52042bc24e3
# 66: 4ab2b0b9f964a520e56b20e3
# 67: 4ba5208ff964a520f5e038e3
# Would be a wasted API call
# 68: 568dcf20498e1601e2f8b87f
# 69: 4ad7929cf964a520500c21e3
# 70: 4fb13c20e4b011e6f93513c0
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# 133: 4ad4c05df964a52055f620e3
# 134: 4ad4c05df964a52039f620e3
# Would be a wasted API call
# Would be a wasted API call
# 135: 536ad71f498eb423d8fc2c6c
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Index: 9
# Central Bay Street
# ------------------------------------------
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# 136: 4aeb711ef964a52017c221e3
# 137: 4f513029e4b07c3382c9fdb9
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# 138: 568bcf61498e3aaff5e351f8
# 139: 4b8c0fa3f964a52085bb32e3
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# 140: 4ae1296df964a5208c8521e3
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# 141: 4ba8f061f964a520e8fb39e3
# Would be a wasted API call
# 142: 4af1b6e5f964a5206be221e3
# Would be a wasted API call
# Would be a wasted API call
# 143: 5707027d498edd885aea5dce
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# 144: 576d6f42cd10a37101171051
# 145: 57ad08e5498eeb743885542b
# 146: 4bd28d6ccaff95213e2ad3f0
# Would be a wasted API call
# Would be a wasted API call
# 147: 5242ec87498ebb98768e0487
# 148: 4e627664a80951b31884cc6b
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call
# Would be a wasted API call

# %%
venue_details.shape
# Out:
# (1481, 8)

# %%
# For now, try always updating pkl file
venue_details.to_pickle("venue_details.pkl")

# %%
# I want to filter down all my data now to the top 10 neighborhoods
top_tor_neigh = toronto_sum["Neighborhood"][0:10]
top_nyc_neigh = nyc_sum["Neighborhood"][0:10]
print(top_tor_neigh)
print(top_nyc_neigh)
# Out:
# 0               First Canadian Place, Underground city
# 1                       Commerce Court, Victoria Hotel
# 2    Harbourfront East, Union Station, Toronto Islands
# 3             Toronto Dominion Centre, Design Exchange
# 4     Stn A PO Boxes, 25 The Esplanade, Enclave of M5E
# 5                             Richmond, Adelaide, King
# 6                             Garden District, Ryerson
# 7                                 Church and Wellesley
# 8                                       St. James Town
# 9                                   Central Bay Street
# Name: Neighborhood, dtype: object
# 0           Murray Hill
# 1            South Side
# 2               Astoria
# 3          East Village
# 4            North Side
# 5             Yorkville
# 6          West Village
# 7       Upper West Side
# 8    Financial District
# 9              Downtown
# Name: Neighborhood, dtype: object

# %%
all_top_venues["Neighborhood"].unique()
# Out:
# array(['Church and Wellesley', 'Garden District, Ryerson',
#        'St. James Town', 'Central Bay Street', 'Richmond, Adelaide, King',
#        'Harbourfront East, Union Station, Toronto Islands',
#        'Toronto Dominion Centre, Design Exchange',
#        'Commerce Court, Victoria Hotel',
#        'Stn A PO Boxes, 25 The Esplanade, Enclave of M5E',
#        'First Canadian Place, Underground city', 'Downtown', 'North Side',
#        'South Side', 'Yorkville', 'Upper West Side', 'Murray Hill',
#        'East Village', 'West Village', 'Financial District', 'Astoria'],
#       dtype=object)

# %% [markdown]
# <h1>This is where I limit all the fun venues data to the Top 10 Neighborhoods</h1>

# %%
# df[df['col1'].isin(['a', 'c', 'h'])]
all_top_venues = all_venues_fun[all_venues_fun["Neighborhood"].isin(top_tor_neigh) | all_venues_fun["Neighborhood"].isin(top_nyc_neigh)]
# Out:
#              Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
#
# 128       -79.384796   Mexican Restaurant    Ethnic Food  Toronto
# 129       -79.380785            Bookstore       FunStore  Toronto
# 130       -79.380683      Thai Restaurant    Ethnic Food  Toronto
# 131       -79.380964           Restaurant      CheapMeal  Toronto
# 132       -79.385353     Ramen Restaurant    Ethnic Food  Toronto
# 133       -79.381068                 Park     Recreation  Toronto
# 134       -79.380427            Juice Bar  CoffeeDessert  Toronto
# 135       -79.380376          Pizza Place    Ethnic Food  Toronto
# 136       -79.380510          Coffee Shop  CoffeeDessert  Toronto
# 137       -79.384814                Diner    Ethnic Food  Toronto
# 138       -79.384125             Creperie    Ethnic Food  Toronto
# 139       -79.384936          Escape Room     Recreation  Toronto
# 140       -79.384767  Martial Arts School     Recreation  Toronto
# 141       -79.380904         Burger Joint      CheapMeal  Toronto
# 142       -79.385510                  Gym     Recreation  Toronto
# 143       -79.386977     Sushi Restaurant    Ethnic Food  Toronto
# 144       -79.380684       Ice Cream Shop  CoffeeDessert  Toronto
# 145       -79.380361              Gay Bar            Bar  Toronto
# 146       -79.384707  Japanese Restaurant    Ethnic Food  Toronto
# 147       -79.384941     Sushi Restaurant    Ethnic Food  Toronto

# %%
all_top_venues[0:50]
# Out:
#              Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 123  Church and Wellesley               43.66586               -79.38316
# 124  Church and Wellesley               43.66586               -79.38316
# 125  Church and Wellesley               43.66586               -79.38316
# 126  Church and Wellesley               43.66586               -79.38316
# 127  Church and Wellesley               43.66586               -79.38316
# 128  Church and Wellesley               43.66586               -79.38316
# 129  Church and Wellesley               43.66586               -79.38316
# 130  Church and Wellesley               43.66586               -79.38316
# 131  Church and Wellesley               43.66586               -79.38316
# 132  Church and Wellesley               43.66586               -79.38316
# 133  Church and Wellesley               43.66586               -79.38316
# 134  Church and Wellesley               43.66586               -79.38316
# 135  Church and Wellesley               43.66586               -79.38316
# 136  Church and Wellesley               43.66586               -79.38316
# 137  Church and Wellesley               43.66586               -79.38316
# 138  Church and Wellesley               43.66586               -79.38316
# 139  Church and Wellesley               43.66586               -79.38316
# 140  Church and Wellesley               43.66586               -79.38316
# 141  Church and Wellesley               43.66586               -79.38316
# 142  Church and Wellesley               43.66586               -79.38316
# 143  Church and Wellesley               43.66586               -79.38316
# 144  Church and Wellesley               43.66586               -79.38316
# 145  Church and Wellesley               43.66586               -79.38316
# 146  Church and Wellesley               43.66586               -79.38316
# 147  Church and Wellesley               43.66586               -79.38316
# 148  Church and Wellesley               43.66586               -79.38316
# 149  Church and Wellesley               43.66586               -79.38316
# 150  Church and Wellesley               43.66586               -79.38316
# 151  Church and Wellesley               43.66586               -79.38316
# 152  Church and Wellesley               43.66586               -79.38316
# 153  Church and Wellesley               43.66586               -79.38316
# 154  Church and Wellesley               43.66586               -79.38316
# 155  Church and Wellesley               43.66586               -79.38316
# 156  Church and Wellesley               43.66586               -79.38316
# 157  Church and Wellesley               43.66586               -79.38316
# 158  Church and Wellesley               43.66586               -79.38316
# 159  Church and Wellesley               43.66586               -79.38316
# 160  Church and Wellesley               43.66586               -79.38316
# 161  Church and Wellesley               43.66586               -79.38316
# 157       -79.385694                Restaurant      CheapMeal  Toronto
# 158       -79.379670                 Gastropub            Bar  Toronto
# 159       -79.380210       Japanese Restaurant    Ethnic Food  Toronto
# 160       -79.383956             Burrito Place    Ethnic Food  Toronto
# 161       -79.380412                   Gay Bar            Bar  Toronto
# 162       -79.377730                   Theater  Entertainment  Toronto
# 163       -79.383636               Yoga Studio     Recreation  Toronto
# 164       -79.379871               Coffee Shop  CoffeeDessert  Toronto
# 165       -79.386686          Sushi Restaurant    Ethnic Food  Toronto
# 166       -79.380040                   Dog Run     Recreation  Toronto
# 167       -79.377471       American Restaurant    Ethnic Food  Toronto
# 168       -79.385287  Mediterranean Restaurant    Ethnic Food  Toronto
# 169       -79.386748   Health & Beauty Service     Recreation  Toronto
# 170       -79.386566          Sushi Restaurant    Ethnic Food  Toronto
# 171       -79.386830                      Café      CheapMeal  Toronto
# 172       -79.384574       Japanese Restaurant    Ethnic Food  Toronto

# %%
# 8-16-2021 - all_top_venues is all the nyc and tor venue data filtered to the top 10 neighs in each city
all_top_venues.to_pickle("all_top_venues.pkl")

# %%
# ADD CITY COLUMNS TO EACH OF THE CITY DATAFRAMES
toronto_venues_fun['City'] = 'Toronto'
nyc_venues_fun['City'] = 'New York'

# %%
#Combine the venues data from toronto and nyc so I can merge the venue_details
all_venues_fun = toronto_venues_fun.append(nyc_venues_fun, ignore_index=True)
all_venues_fun.head()
# Out:
#        Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0     Lawrence Park              43.728020              -79.388790
# 1     Lawrence Park              43.728020              -79.388790
# 2  Davisville North              43.712751              -79.390197
# 3  Davisville North              43.712751              -79.390197
# 4  Davisville North              43.712751              -79.390197
#
#                    Venue_Id                        Venue  Venue Latitude  \
# 0  50e6da19e4b0d8a78a0e9794         Lawrence Park Ravine       43.726963
# 1  5082ef77e4b0a7491cf7b022           Zodiac Swim School       43.728532
# 2  4ba011c2f964a5204a5737e3                Sherwood Park       43.716551
# 3  4adb2fd3f964a520c42421e3  Homeway Restaurant & Brunch       43.712641
# 4  4b0b3691f964a520c62e23e3                       Subway       43.708474
#
#    Venue Longitude  Venue Category SimpleCategory     City
# 0       -79.394382            Park     Recreation  Toronto
# 1       -79.382860     Swim School     Recreation  Toronto
# 2       -79.387776            Park     Recreation  Toronto
# 3       -79.391557  Breakfast Spot      CheapMeal  Toronto
# 4       -79.390674  Sandwich Place      CheapMeal  Toronto

# %%
all_venues_fun.to_pickle("all_venues_fun.pkl")

# %% [markdown]
# <h1>Merge all venues with all venue details now
# BUT - I think this should be focused on the top 10 neighborhoods for Tor and Nyc!</h1>

# %%
all_venues_and_details = all_venues_fun.merge(venue_details,how="left", on="Venue_Id")

# %%
all_venues_and_details[1000:1040] #[1370:1415]
# Out:
#                                 Neighborhood  Neighborhood Latitude  \
# 1000  First Canadian Place, Underground city              43.648429
# 1001  First Canadian Place, Underground city              43.648429
# 1002  First Canadian Place, Underground city              43.648429
# 1003  First Canadian Place, Underground city              43.648429
# 1004  First Canadian Place, Underground city              43.648429
# 1005  First Canadian Place, Underground city              43.648429
# 1006  First Canadian Place, Underground city              43.648429
# 1007  First Canadian Place, Underground city              43.648429
# 1010       -79.380957               Coffee Shop  CoffeeDessert  Toronto
# 1011       -79.382544               Coffee Shop  CoffeeDessert  Toronto
# 1012       -79.385724                Steakhouse     Fancy Food  Toronto
# 1013       -79.383412                Food Court      CheapMeal  Toronto
# 1014       -79.380347                 Bookstore       FunStore  Toronto
# 1015       -79.381376                  Beer Bar            Bar  Toronto
# 1016       -79.378068                       Gym     Recreation  Toronto
# 1017       -79.384863       Japanese Restaurant    Ethnic Food  Toronto
# 1018       -79.381744       Monument / Landmark     Recreation  Toronto
# 1019       -79.388381  Mediterranean Restaurant    Ethnic Food  Toronto
# 1020       -79.383075                       Gym     Recreation  Toronto
# 1021       -79.380574                  Wine Bar            Bar  Toronto
# 1022       -79.381681              Burger Joint      CheapMeal  Toronto
# 1023       -79.388090          Sushi Restaurant    Ethnic Food  Toronto
# 1024       -79.387530                   Theater  Entertainment  Toronto
# 1025       -79.386457       Japanese Restaurant    Ethnic Food  Toronto
# 1026       -79.386242               Opera House  Entertainment  Toronto
# 1027       -79.386328                Steakhouse     Fancy Food  Toronto
# 1028       -79.379045                    Bakery  CoffeeDessert  Toronto
# 1029       -79.381044             Deli / Bodega      CheapMeal  Toronto
# 1030       -79.379181        Seafood Restaurant     Fancy Food  Toronto
# 1031       -79.383046          Asian Restaurant    Ethnic Food  Toronto
# 1032       -79.382325       Fried Chicken Joint      CheapMeal  Toronto
# 1033       -79.383798           Thai Restaurant    Ethnic Food  Toronto
# 1034       -79.381956                       Bar            Bar  Toronto
# 1035       -79.383065               Coffee Shop  CoffeeDessert  Toronto
# 1036       -79.386091      Colombian Restaurant    Ethnic Food  Toronto
# 1037       -79.383748               Salad Place    Ethnic Food  Toronto
# 1038       -79.381600           Thai Restaurant    Ethnic Food  Toronto
# 1039       -79.382572               Coffee Shop  CoffeeDessert  Toronto
#
#                                            Name  TipsCount  LikesCount  \
# 1000                              Olly Fresco's        4.0        18.0
# 1001                               Chotto Matte        2.0        13.0
# 1002                                  The Chase       59.0       145.0
# 1003  Hockey Hall Of Fame (Hockey Hall of Fame)       79.0       407.0
# 1004                                        NaN        NaN         NaN
# 1005         iQ Food Co. (First Canadian Place)        1.0         7.0
# 1006                                 Beerbistro      128.0       323.0
# 1007                                 Sweet Lulu       11.0        17.0
# 1008                      Pilot Coffee Roasters       12.0        50.0
# 1009                                        NaN        NaN         NaN
# 1010                                  Starbucks        9.0        28.0
# 1011                                Tim Hortons        4.0        10.0
# 1012                   Ruth's Chris Steak House       25.0        59.0
# 1013                       Assembly Chef's Hall       15.0        70.0
# 1014                               Indigospirit        0.0         8.0
# 1015                                      WVRST        8.0        20.0
# 1016  GoodLife Fitness Toronto 137 Yonge Street       30.0       125.0
# 1017                              Ninki Izakaya        5.0         9.0
# 1018                              Old City Hall       22.0        73.0
# 1019                                        NaN        NaN         NaN
# 1020                                        NaN        NaN         NaN
# 1021                          The National Club        5.0        17.0
# 1022                                  Five Guys        0.0         3.0
# 1023                                        NaN        NaN         NaN
# 1024                                        NaN        NaN         NaN
# 1025                                        NaN        NaN         NaN
# 1026                                        NaN        NaN         NaN
# 1027                                        NaN        NaN         NaN
# 1028                                  Sud Forno       11.0        56.0
# 1029                                        NaN        NaN         NaN
# 1030                          Buster's Sea Cove        2.0         9.0
# 1031                                        NaN        NaN         NaN
# 1032                              Union Chicken        5.0        17.0
# 1033                                        NaN        NaN         NaN
# 1034                   Boxcar Social Temperance        7.0        34.0
# 1035                            Balzac's Coffee        6.0        22.0
# 1036                                        NaN        NaN         NaN
# 1037                                        NaN        NaN         NaN
# 1038           Ruby Thai (First Canadian Place)        2.0         7.0
# 1039                                        NaN        NaN         NaN
#
#       Rating  RatingSignals PriceTier  VoteSum
# 1000     7.8           23.0         1     63.0
# 1001     8.2           16.0         2     44.0
# 1002     8.2          212.0         3    561.0
# 1003     8.7          501.0       NaN   1394.0
# 1004     NaN            NaN       NaN      NaN
# 1005     7.4            9.0         1     24.0
# 1006     8.6          478.0         2   1252.0
# 1007     7.6           28.0         2     73.0
# 1008     8.4           69.0         1    181.0
# 1009     NaN            NaN       NaN      NaN
# 1010     7.4           46.0         1    111.0
# 1011     7.4           15.0         1     39.0
# 1012     7.8           91.0         2    234.0
# 1013     7.6           98.0       NaN    253.0
# 1014     7.4            9.0       NaN     25.0
# 1015     8.2           28.0       NaN     76.0
# 1016     8.7          161.0       NaN    441.0
# 1017     7.6           15.0         2     38.0
# 1018     8.1           96.0       NaN    264.0
# 1019     NaN            NaN       NaN      NaN
# 1020     NaN            NaN       NaN      NaN
# 1021     7.3           25.0         2     64.0
# 1022     7.3            3.0         1      9.0
# 1023     NaN            NaN       NaN      NaN
# 1024     NaN            NaN       NaN      NaN
# 1025     NaN            NaN       NaN      NaN
# 1026     NaN            NaN       NaN      NaN
# 1027     NaN            NaN       NaN      NaN
# 1028     7.8           80.0         1    203.0
# 1029     NaN            NaN       NaN      NaN
# 1030     7.3           12.0         3     32.0
# 1031     NaN            NaN       NaN      NaN
# 1032     7.7           28.0         1     67.0
# 1033     NaN            NaN       NaN      NaN
# 1034     7.2           45.0         2    120.0
# 1035     8.0           28.0         1     78.0
# 1036     NaN            NaN       NaN      NaN
# 1037     NaN            NaN       NaN      NaN
# 1038     7.1           10.0         2     26.0
# 1039     NaN            NaN       NaN      NaN

# %% [markdown]
# <H1>This is where I create the concept of a general Score for each venue</H1>

# %%
# all_venues_and_details.sort_values(by="VoteSum", ascending=False)[0:50]
# all_venues_and_details["Score"] = all_venues_and_details["VoteSum"] * all_venues_and_details["Rating"]
all_venues_and_details.sort_values(by="Score", ascending=False)[50:100]
# Out:
#                                           Neighborhood  Neighborhood Latitude  \
# 5606                                      West Village              40.734434
# 4765                                   Upper West Side              40.787658
# 5603                                      West Village              40.734434
# 5573                                              Soho              40.722184
# 6939                                          Steinway              40.775923
# 5580                                              Soho              40.722184
# 6935                                          Steinway              40.775923
# 5612                                      West Village              40.734434
# 4742                                   Upper West Side              40.787658
# 206                          Regent Park, Harbourfront              43.654260
# 495                           Richmond, Adelaide, King              43.650571
# 302                                     St. James Town              43.651494
# 715                     Commerce Court, Victoria Hotel              43.648198
# 5612     8.7          666.0         3   1756.0  15277.2
# 4742     8.5          671.0         2   1727.0  14679.5
# 206      8.1          707.0         3   1809.0  14652.9
# 495      8.7          634.0         2   1684.0  14650.8
# 302      8.7          634.0         2   1684.0  14650.8
# 715      8.7          634.0         2   1684.0  14650.8
# 984      8.7          634.0         2   1684.0  14650.8
# 650      8.7          634.0         2   1684.0  14650.8
# 4829     7.6          780.0         0   1870.0  14212.0
# 5550     9.3          543.0         2   1503.0  13977.9
# 5451     9.3          543.0         2   1503.0  13977.9
# 215      7.8          716.0         2   1772.0  13821.6
# 5618     8.6          585.0         0   1576.0  13553.6
# 4806     8.4          922.0         3   1574.0  13221.6
# 5613     8.6          857.0         3   1506.0  12951.6
# 4730     8.6          544.0         1   1467.0  12616.2
# 4916     8.0          625.0         2   1574.0  12592.0
# 5480     8.9          500.0         3   1376.0  12246.4
# 5564     8.9          500.0         3   1376.0  12246.4
# 357      8.7          501.0       NaN   1394.0  12127.8
# 708      8.7          501.0       NaN   1394.0  12127.8
# 1003     8.7          501.0       NaN   1394.0  12127.8
# 882      8.7          501.0       NaN   1394.0  12127.8
# 639      8.7          501.0       NaN   1394.0  12127.8
# 4820     8.1          554.0         3   1481.0  11996.1
# 4769     8.0          579.0         2   1493.0  11944.0
# 5464     8.8          493.0         3   1323.0  11642.4
# 5570     8.8          493.0         3   1323.0  11642.4
# 4800     9.2          441.0         0   1245.0  11454.0
# 5631     8.8          475.0         3   1289.0  11343.2
# 5585     9.1          444.0         3   1221.0  11111.1
# 193      9.3          658.0         0   1182.0  10992.6
# 712      8.6          478.0         2   1252.0  10767.2
# 654      8.6          478.0         2   1252.0  10767.2
# 894      8.6          478.0         2   1252.0  10767.2
# 1006     8.6          478.0         2   1252.0  10767.2
# 300      8.6          478.0         2   1252.0  10767.2
# 663      7.4          589.0         2   1423.0  10530.2
# 4774     7.8          513.0         2   1349.0  10522.2
# 5542     8.7          457.0         3   1201.0  10448.7
# 4725     8.8          434.0         2   1177.0  10357.6
# 5578     8.7          445.0         0   1190.0  10353.0
# 5501     8.7          445.0         0   1190.0  10353.0

# %%
all_venues_and_details.to_pickle("all_venues_and_details.pkl")

# %%
toronto_venues_fun.shape #1622
#nyc_venues_fun.shape # 7495
# Out:
# (1622, 10)

# %% [markdown]
# <H1>This is where I added the City column into the venue details</H1>

# %%
# Combine whatever data we have in the venue details with what we have in toronto venues
# MERGE IN TORONTO
#city_fun = venue_details.merge(toronto_venues_fun, how='left', on='Venue_Id',left_index=True)

# MERGE IN NYC
city_fun = venue_details.merge(nyc_venues_fun, how='left', on='Venue_Id',left_index=True)

# %%
# BE CAREFUL WITH RUNNING THIS
# city_fun['City'] = 'Toronto'
#city_fun['City'] = 'Toronto'
city_fun[city_fun['Neighborhood'].isnull()==False]
#city_fun.head(30)
# Out:
#                         Venue_Id  \
# 6007.0  4d3e1be3ae942d43e09e9f9a
# 6009.0  5e44505ffdc6610008c7d741
# 6010.0  4c671600aebea593c63075d0
# 6012.0  4b9a8df9f964a520acc035e3
# 6013.0  52f693e6498ed9d2a3fbad75
# ...                          ...
# 9907.0  4bbe631782a2ef3b764b2bd2
# 9909.0  4bd60bf4cfa7b713faec26da
# 9911.0  53372ea7498ed5a1955d86ef
# 9914.0  599b1f75ca18ea189fe0dfff
# 9915.0  4bc63c3651b376b095391b6f
#
#                                                      Name  TipsCount  \
# 6007.0                             El Pequeno Coffee Shop         14
# 6009.0                                              Thaan          1
# 6010.0                                      Casa Colombia          3
# 6012.0                              La Gata Golosa Bakery          7
# 6013.0  Eim Khao Mun Kai Elmhurst อิ่ม ข้าวมันไก่เอ็มเ...         26
# ...                                                   ...        ...
# 9907.0                        Ralph's Famous Italian Ices         10
# 9909.0                                               Toyo         11
# 9911.0                                     Rico's Chicken          2
# 9914.0  The Salvation Army Family Store & Donation Center          0
# 9915.0                                             SUBWAY          7
#
#         LikesCount  Rating  RatingSignals PriceTier  VoteSum     Neighborhood  \
# 6007.0           9     6.1             23         2       55  Jackson Heights
# 6009.0           1     0.0              0         2        3  Jackson Heights
# 6010.0           4     5.8              9         2       20  Jackson Heights
# 6012.0           8     5.6             17         1       40  Jackson Heights
# 6013.0          99     8.7            128         1      352         Elmhurst
# ...            ...     ...            ...       ...      ...              ...
# 9907.0          13     8.2             22         1       58   Middle Village
# 9909.0          17     7.7             28         2       73   Middle Village
# 9911.0          11     7.3             13         2       37   Middle Village
# 9914.0           0     6.5              0         0        0   Middle Village
# 9915.0           1     6.3              6         1       15   Middle Village
#
#         Neighborhood Latitude  Neighborhood Longitude  \
# 6007.0              40.751981              -73.882821
# 6009.0              40.751981              -73.882821
# 6010.0              40.751981              -73.882821
# 6012.0              40.751981              -73.882821
# 6013.0              40.744049              -73.881656
# ...                       ...                     ...
# 9907.0              40.716415              -73.881143
# 9909.0              40.716415              -73.881143
# 9911.0              40.716415              -73.881143
# 9914.0              40.716415              -73.881143
# 9915.0              40.716415              -73.881143
#
#                                                     Venue  Venue Latitude  \
# 6007.0                             El Pequeno Coffee Shop       40.748083
# 6009.0                                              Thaan       40.749849
# 6010.0                                      Casa Colombia       40.748263
# 6012.0                              La Gata Golosa Bakery       40.750458
# 6013.0  Eim Khao Mun Kai Elmhurst อิ่ม ข้าวมันไก่เอ็มเ...       40.743014
# ...                                                   ...             ...
# 9907.0                        Ralph's Famous Italian Ices       40.712856
# 9909.0                                               Toyo       40.712611
# 9911.0                                     Rico's Chicken       40.713009
# 9914.0  The Salvation Army Family Store & Donation Center       40.712672
# 9915.0                                             SUBWAY       40.712513
#
#         Venue Longitude             Venue Category SimpleCategory
# 6007.0       -73.880205  Latin American Restaurant    Ethnic Food
# 6009.0       -73.881865            Thai Restaurant    Ethnic Food
# 6010.0       -73.879485  South American Restaurant    Ethnic Food
# 6012.0       -73.877701  South American Restaurant    Ethnic Food
# 6013.0       -73.883057            Thai Restaurant    Ethnic Food
# ...                 ...                        ...            ...
# 9907.0       -73.879132               Dessert Shop  CoffeeDessert
# 9909.0       -73.878948           Sushi Restaurant    Ethnic Food
# 9911.0       -73.877336  South American Restaurant    Ethnic Food
# 9914.0       -73.878501     Thrift / Vintage Store       FunStore
# 9915.0       -73.879386             Sandwich Place      CheapMeal
#
# [107 rows x 16 columns]

# %%
city_fun.tail()
# Out:
#                      Venue_Id  \
# NaN  4bbe631782a2ef3b764b2bd2
# NaN  4bd60bf4cfa7b713faec26da
# NaN  53372ea7498ed5a1955d86ef
# NaN  599b1f75ca18ea189fe0dfff
# NaN  4bc63c3651b376b095391b6f
#
#                                                   Name  TipsCount  LikesCount  \
# NaN                        Ralph's Famous Italian Ices         10          13
# NaN                                               Toyo         11          17
# NaN                                     Rico's Chicken          2          11
# NaN  The Salvation Army Family Store & Donation Center          0           0
# NaN                                             SUBWAY          7           1
#
#      Rating  RatingSignals PriceTier  VoteSum Neighborhood  \
# NaN     8.2             22         1       58          NaN
# NaN     7.7             28         2       73          NaN
# NaN     7.3             13         2       37          NaN
# NaN     6.5              0         0        0          NaN
# NaN     6.3              6         1       15          NaN
#
#      Neighborhood Latitude  Neighborhood Longitude Venue  Venue Latitude  \
# NaN                    NaN                     NaN   NaN             NaN
# NaN                    NaN                     NaN   NaN             NaN
# NaN                    NaN                     NaN   NaN             NaN
# NaN                    NaN                     NaN   NaN             NaN
# NaN                    NaN                     NaN   NaN             NaN
#
#      Venue Longitude Venue Category SimpleCategory     City
# NaN              NaN            NaN            NaN  Toronto
# NaN              NaN            NaN            NaN  Toronto
# NaN              NaN            NaN            NaN  Toronto
# NaN              NaN            NaN            NaN  Toronto
# NaN              NaN            NaN            NaN  Toronto

# %%
# To remove rows by index
# venue_details = venue_details.drop(index=[12,13])
venue_details.tail(40)
# Out:
#                      Venue_Id  \
# 559  4b7ff72ff964a520684730e3
# 560  4c377a13ae2da59377f4fec5
# 561  51c3a999498e5db561b5346a
# 562  4b97f9ebf964a520822335e3
# 563  46b1ef0df964a520a0491fe3
# 564  4b7d8e1af964a5205dc62fe3
# 565  4bb6860ef562ef3b4c513097
# 566  54568cc5498ed42af61bc55d
# 567  4c64b110ee03ef3b735dbaac
# 568  4f6cb7a0e4b0a6b770c9b395
# 569  4c914db7b641236acc648079
# 570  5ffa14f983f8904fe5785e11
# 571  4b042d74f964a520d05122e3
# 572  4c4594b1dcd61b8d0ad97c56
# 573  59824f61ad1ea40bd671a3a6
# 574  4f21f794e4b03bdcfa48c587
# 575  5a8237ddb6eedb04cf7abbf4
# 576  4a998174f964a520b62e20e3
# 577  529b754c11d255231f7e54e5
# 578  4bc90857937ca5936d19a592
# 579  4c9e27ea54c8a1cdabb68a4b
# 580  56228cdd498e3dc5e84fcd15
# 581  5f1db360549e6512d38fb6cc
# 582  4b928bc0f964a520f90234e3
# 583  4c3246bfa0ced13aebe2146e
# 584  4a3ada26f964a5205fa01fe3
# 585  4e4dd5d0bd4101d0d79c52f9
# 586  4ca6967076d3a093e645036b
# 587  4ba68cbaf964a520605d39e3
# 588  4f3c5cb4e4b02d5ef78d79bc
# 589  4b57bdccf964a520d33e28e3
# 590  4c7a604b2d3ba143a20c91d0
# 591  4bb65aab2ea195215a8aab2f
# 592  4b8768c1f964a52095be31e3
# 593  53989edf498e85ce86d65ea2
# 594  4bbe631782a2ef3b764b2bd2
# 595  4bd60bf4cfa7b713faec26da
# 596  53372ea7498ed5a1955d86ef
# 597  599b1f75ca18ea189fe0dfff
# 598  4bc63c3651b376b095391b6f
#
#                                                   Name  TipsCount  LikesCount  \
# 559                                Forest Hills Bagels         24          86
# 560                                   Yellowstone Park          4          21
# 561                                    iLoveKickboxing         21           6
# 562                                     MacDonald Park          8          31
# 563                                    Bangkok Cuisine         34          62
# 564                                         bambooYOGA         11          13
# 565                             Empire Wines & Liquors          6          25
# 566                                 Tu Casa Restaurant          4          10
# 567                                       Zen and Yoga          2          14
# 568                                       Gloria Pizza         20          39
# 569                                      Fast Break 24          1           8
# 570                                          Starbucks          0           2
# 571                             Sahara Halal Food Cart          9           9
# 572                           Central Queens YM & YMHA          3          21
# 573                                 Rosalia's Pizzeria          3           6
# 574              International Karate & Fitness Center          1           6
# 575                                          Numero 28          1           7
# 576                              New York Sports Clubs         46          93
# 577                                    The Boiler Room          0           6
# 578                                           Thai Pot         12          16
# 579                                       Ka Ka Bakery          8           7
# 580                                             Subway          0           0
# 581                                            Dunkin'          0           0
# 582                              Three Star Restaurant          8          28
# 583                                            Dunkin'          0           4
# 584                      La Villita Mexican Restaurant          6           8
# 585                                            Dunkin'          1           0
# 586                                         Red Lounge          2          11
# 587                                   Luigi's Pizzeria          8           8
# 588                                       Sushi MiKasa          6           8
# 589                     Coney Island Bagels And Bialys          4           2
# 590                                Coffee Shop - Ave U          0           0
# 591               Juniper Valley Park Playground South          3          17
# 592                                Juniper Valley Park         28         120
# 593                                       Villa Erasmo          4          17
# 594                        Ralph's Famous Italian Ices         10          13
# 595                                               Toyo         11          17
# 596                                     Rico's Chicken          2          11
# 597  The Salvation Army Family Store & Donation Center          0           0
# 598                                             SUBWAY          7           1
#
#      Rating  RatingSignals PriceTier  VoteSum
# 559     9.0            113         1      309
# 560     7.9             26         0       72
# 561     8.9             27         0       60
# 562     8.1             41         0      111
# 563     8.5             93         1      251
# 564     8.1             18         0       55
# 565     8.0             35         0       91
# 566     7.9             15         2       39
# 567     8.0             17         0       47
# 568     7.9             65         1      163
# 569     7.3             11         1       28
# 570     7.4              2         1        6
# 571     7.6             19         1       46
# 572     7.2             28         0       73
# 573     7.1             10         1       25
# 574     6.8              8         0       21
# 575     6.5             14         2       29
# 576     6.5            162         0      394
# 577     6.3              9         0       21
# 578     6.3             33         1       77
# 579     6.8             15         1       37
# 580     6.6              0         1        0
# 581     6.5              0         1        0
# 582     6.4             50         2      114
# 583     6.1              7         1       15
# 584     6.1             18         1       40
# 585     6.4              1         1        2
# 586     5.9             19         3       43
# 587     6.1             20         1       44
# 588     6.1             21         2       43
# 589     0.0              0         1        8
# 590     0.0              0         1        0
# 591     8.4             18         0       55
# 592     9.2            149         0      417
# 593     8.4             22         2       60
# 594     8.2             22         1       58
# 595     7.7             28         2       73
# 596     7.3             13         2       37
# 597     6.5              0         0        0
# 598     6.3              6         1       15

# %%
nyc_sum.head()
# Murray Hill is #1
# Out:
#    index  Neighborhood  Bar  CheapMeal  CoffeeDessert  Entertainment  \
# 0    184   Murray Hill   11         19             14              2
# 1    252    South Side   22         10              9              2
# 2      6       Astoria   14         13             13              0
# 3     81  East Village   20          7             11              2
# 4    194    North Side   17          7             21              2
#
#    Ethnic Food  Fancy Food  FunStore  Recreation  TotalFun
# 0           59           5         0          13       123
# 1           35           3         1           8        90
# 2           38           4         0           7        89
# 3           40           1         5           3        89
# 4           29           2         2           6        86

# %%
nyc_venues_fun[(nyc_venues_fun["Neighborhood"] == "Clinton") & (nyc_venues_fun["SimpleCategory"] == "Entertainment")]
# Out:
#      Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 4342      Clinton              40.759101              -73.996119
# 4344      Clinton              40.759101              -73.996119
# 4346      Clinton              40.759101              -73.996119
# 4358      Clinton              40.759101              -73.996119
# 4359      Clinton              40.759101              -73.996119
# 4367      Clinton              40.759101              -73.996119
# 4373      Clinton              40.759101              -73.996119
# 4388      Clinton              40.759101              -73.996119
# 4392      Clinton              40.759101              -73.996119
#
#                       Venue_Id                                Venue  \
# 4342  4b6a09cff964a5206ac32be3    Pershing Square Signature Theater
# 4344  4c379ecf1e06d13a4e49763e                 Playwrights Horizons
# 4346  5a235575e179100e0425abc7           UCB Theatre Hell’s Kitchen
# 4358  5711b92e498e677b825cc78d          Yotel - Rooftop Cinema Club
# 4359  4b6cdf69f964a520af5a2ce3                    The Actors Studio
# 4367  4a0b4df9f964a520e8741fe3              Baryshnikov Arts Center
# 4373  4ab424b4f964a520117020e3                 The Westside Theater
# 4388  4fa709c3e4b047f0ed7001d7  The Alice Griffin Jewel Box Theatre
# 4392  58a3c4cce9dad156c1d43d93                        Green Room 42
#
#       Venue Latitude  Venue Longitude         Venue Category SimpleCategory
# 4342       40.759228       -73.995232                Theater  Entertainment
# 4344       40.758818       -73.993574                Theater  Entertainment
# 4346       40.760500       -73.997863            Comedy Club  Entertainment
# 4358       40.759429       -73.995047          Movie Theater  Entertainment
# 4359       40.760339       -73.993280                Theater  Entertainment
# 4367       40.756283       -73.997181                Theater  Entertainment
# 4373       40.759350       -73.992765          Indie Theater  Entertainment
# 4388       40.759463       -73.995185                Theater  Entertainment
# 4392       40.759448       -73.995083  Performing Arts Venue  Entertainment

# %%
import numpy as np
import pandas as pd
import folium # map rendering library

# %%
all_venues_fun = pd.read_pickle("all_venues_fun.pkl")

# %%
venue_details = pd.read_pickle("venue_details.pkl")
venue_details.shape
# Out:
# (2377, 8)

# %%
#  This is basically all the venues in either NYC or TOR that have detail data
venues_with_details = venue_details.merge(all_venues_fun, on="Venue_Id", how="inner")
venues_with_details.shape
# Out:
# (2918, 17)

# %%
# venues_with_details has venue details outside of my top 10 neighborhoods from each city
# df[df['col1'].isin(['a', 'c', 'h'])]

top_tor = ['First Canadian Place, Underground city','Commerce Court, Victoria Hotel','Harbourfront East, Union Station, Toronto Islands','Toronto Dominion Centre, Design Exchange','Stn A PO Boxes, 25 The Esplanade, Enclave of M5E','Richmond, Adelaide, King','Garden District, Ryerson','Church and Wellesley','St. James Town','Central Bay Street']
top_nyc = ['Murray Hill','South Side','Astoria','East Village','North Side','Yorkville','West Village','Upper West Side','Financial District','Downtown']

topvenuedetails = venues_with_details[((venues_with_details['City'] == 'Toronto')\
                                      & (venues_with_details['Neighborhood'].isin(top_tor)))\
                                      | ((venues_with_details['City'] == 'New York')\
                                      & (venues_with_details['Neighborhood'].isin(top_nyc)))]

# %%
# THIS IS SOME GREAT DATA HERE - All venue details for top 10 neighs in Tor and Nyc
topvenuedetails.to_pickle("topvenuedetails.pkl")

# %%
# 900 items for nyc
topvenuedetails[topvenuedetails['City']=='New York'].shape
# Out:
# (900, 17)

# %%
nyc_details = topvenuedetails[topvenuedetails['City']=='New York']

# %%
# 750 items for nyc
topvenuedetails[topvenuedetails['City']=='Toronto'].shape
# Out:
# (750, 17)

# %%
tor_details = topvenuedetails[topvenuedetails['City']=='Toronto']

# %%
# Save venues_with_details
venues_with_details.to_pickle("venues_with_details.pkl")

# %%
tor_details = venues_with_details[(venues_with_details["City"]=="Toronto") & (venues_with_details["Rating"].isnull()==False) & (venues_with_details["Rating"] > 3)]
tor_details[0:50]
# Out:
#                     Venue_Id                                Name  TipsCount  \
# 0   537befcc498edb1da559269b  Symposium Cafe Restaurant & Lounge         11
# 1   4b75ce6af964a5201b262ee3                              Subway          2
# 6   4b5fcadff964a520eecc29e3                          Wingporium         24
# 7   4bc9f9b6b6c49c7469688f91                    South St. Burger         11
# 8   4b1d492af964a520370e24e3                Artisano Bakery Café         24
# 9   4c116455d41e76b09552310d                              Subway          0
# 14  4b017e51f964a520d84222e3                                LCBO          8
# 15  5cebda3300b068002dca9d81                           Starbucks          1
# 16  4b251b4cf964a520586c24e3                      Cafe Sympatico          6
# 17  4cb4e17052edb1f7745763fe                           Pizza Hut          0
# 19  54089623498e19198cf69267                           Starbucks          2
# 20  4da8bc62fa8cc76497075931                 Pizza Hut Etobicoke          1
# 21  4b9b0499f964a52020ec35e3                              Subway          0
# 25  4be70e26cf200f47e334153c           Popeyes Louisiana Kitchen          0
# 26  4c633939e1621b8d48842553                              Subway          0
# 27  4d8ba6910c4e41bdaaf7667f                         Pizza Pizza          0
# 28  4cd9d00734bb8cfa6576babf                         Tim Hortons          7
# 32  4db8469e815445bd47d007a2               Quesada Mexican Grill          3
# 33  4c3285463896e21ec8b8e890                         Tim Hortons          1
# 34  4c4dc619fb742d7f8d1f4a2d                              Subway          0
# 35  4c7299ddd944224bc00e0d29                         Tim Hortons          1
# 36  4bda02df63c5c9b6a4412268         Mary Brown's Famous Chicken          4
# 37  4b10219cf964a520ac6923e3                           Starbucks         23
# 45  4ada3af3f964a520482021e3                    CF Fairview Mall         69
# 46  4ae083d4f964a520d47f21e3               Moxie's Classic Grill         56
# 47  4b9413a4f964a5204f6634e3                          SilverCity         21
# 48  4b785a0ef964a520a4c72ee3                  Purdys Chocolatier          6
# 49  4bbaa0f17421a5937311c440                   Michel's Baguette         12
# 50  51313533e4b0ed892d83f3f7                       Booster Juice          0
# 51  51212da18055ce6af0c027d7              Hero Certified Burgers          5
# 52  50bceb3ae4b01dc9b287cc99                  Aroma Espresso Bar          6
# 53  4af5d36ef964a52062fd21e3                           Starbucks         10
# 54  4bbe84be82a2ef3b37912bd2            Fairview Library Theatre          3
# 55  4b9c0249f964a5204d4036e3                  Ten Ren's Tea Time          5
# 56  502fc355e4b0b49bb5791038                         Tim Hortons          0
# 57  5567bf49498e711ea9c1f3fd                         Tim Hortons          1
# 58  5952e5ed491be7022cf5d19f                         Heart Sushi          3
# 59  4c3f205c80bc20a1d1ecab58                         Tim Hortons          0
# 60  4af60327f964a5202e0022e3                                LCBO          5
# 61  4ae1aee0f964a520be8621e3                        Spring Rolls         28
# 62  4afcc133f964a5209b2522e3               St. Louis Bar & Grill         29
# 63  4b9807b2f964a520662735e3                              Z•teca         14
# 68  4bd396d041b9ef3b799c00e6       Sun Star Chinese Cuisine 翠景小炒          0
# 69  4bdc7dd8c79cc9287ecc86e9         Maxim's Cafe and Patisserie         10
# 72  5a02789d0a464d3112a58785                       Konjiki Ramen          8
# 73  4aedfeadf964a52005d121e3                           Starbucks         26
# 74  4ad4c062f964a520e2f720e3                    Cineplex Cinemas         33
# 75  5a46b1016e4650136e1dc52b                               Saryo          2
# 76  557767bc498ea4a20c8043f6                  Aroma Espresso Bar          3
# 77  591491796bd36b1faf45e96b                         Dairy Queen          1
#
#     LikesCount  Rating  RatingSignals PriceTier  VoteSum  \
# 0           30     6.4             52         4      123
# 1            0     5.9              5         1        7
# 6           44     8.0             69         2      181
# 7           25     8.1             35         1       96
# 8           34     6.4             72         2      164
# 9            1     6.2              3         1        5
# 14          29     7.4             41       NaN      107
# 15           2     6.9              3         1        8
# 16           7     6.5             13         1       33
# 17           1     6.4              1         1        3
# 19          15     7.0             23         1       55
# 20           1     6.3              2         1        5
# 21           1     6.4              1         1        3
# 25           0     6.5              0         1        0
# 26           2     6.4              3         1        7
# 27           1     6.1              2         1        4
# 28          11     5.7             24         1       53
# 32          12     7.6             16         1       43
# 33           2     6.2              5         1       10
# 34           1     6.4              3         1        5
# 35           2     6.4              3         1        8
# 36           6     6.1             14         1       30
# 37          51     5.9             95         2      220
# 45         186     7.5            709       NaN     1150
# 46          75     7.7            147         2      353
# 47         164     7.2            230       NaN      579
# 48           8     7.2             11       NaN       33
# 49          26     7.1             43         2      107
# 50           3     6.9              3         1        9
# 51           7     6.9             10         1       29
# 52          13     6.9             20         1       52
# 53          39     6.9             61         2      149
# 54           3     6.8              8       NaN       17
# 55           3     6.7              8         1       19
# 56           1     6.3              2         1        4
# 57           4     6.7              6         1       15
# 58           5     6.2             11         2       24
# 59           1     6.4              1         1        3
# 60          12     6.0             20       NaN       49
# 61          30     6.0             66         2      154
# 62          34     5.8             78         2      175
# 63          11     5.9             26         1       62
# 68           7     6.6             10         1       24
# 69          11     5.8             26         1       58
# 72          39     8.4             49       NaN      135
# 73          85     7.9            124         2      320
# 74         172     7.4            241       NaN      618
# 75          11     7.7             12         1       36
# 76          21     7.2             28         1       73
# 77           3     7.3              5         1       12
#
#                                          Neighborhood  Neighborhood Latitude  \
# 0                                   Willowdale, South              43.770120
# 1                              Alderwood, Long Branch              43.602414
# 6   Mimico NW, The Queensway West, South of Bloor,...              43.628841
# 7   Mimico NW, The Queensway West, South of Bloor,...              43.628841
# 8   Mimico NW, The Queensway West, South of Bloor,...              43.628841
# 9   Mimico NW, The Queensway West, South of Bloor,...              43.628841
# 14  Eringate, Bloordale Gardens, Old Burnhamthorpe...              43.643515
# 15  Eringate, Bloordale Gardens, Old Burnhamthorpe...              43.643515
# 16  Eringate, Bloordale Gardens, Old Burnhamthorpe...              43.643515
# 17  Eringate, Bloordale Gardens, Old Burnhamthorpe...              43.643515
# 19                                          Westmount              43.696319
# 20                                          Westmount              43.696319
# 21                                          Westmount              43.696319
# 25  South Steeles, Silverstone, Humbergate, Jamest...              43.739416
# 26  South Steeles, Silverstone, Humbergate, Jamest...              43.739416
# 27  South Steeles, Silverstone, Humbergate, Jamest...              43.739416
# 28  South Steeles, Silverstone, Humbergate, Jamest...              43.739416
# 32  Canada Post Gateway Processing Centre, Enclave...              43.636966
# 33  Canada Post Gateway Processing Centre, Enclave...              43.636966
# 34  Canada Post Gateway Processing Centre, Enclave...              43.636966
# 35  Canada Post Gateway Processing Centre, Enclave...              43.636966
# 36  Canada Post Gateway Processing Centre, Enclave...              43.636966
# 37  Canada Post Gateway Processing Centre, Enclave...              43.636966
# 45                       Fairview, Henry Farm, Oriole              43.778517
# 46                       Fairview, Henry Farm, Oriole              43.778517
# 47                       Fairview, Henry Farm, Oriole              43.778517
# 48                       Fairview, Henry Farm, Oriole              43.778517
# 49                       Fairview, Henry Farm, Oriole              43.778517
# 50                       Fairview, Henry Farm, Oriole              43.778517
# 51                       Fairview, Henry Farm, Oriole              43.778517
# 52                       Fairview, Henry Farm, Oriole              43.778517
# 53                       Fairview, Henry Farm, Oriole              43.778517
# 54                       Fairview, Henry Farm, Oriole              43.778517
# 55                       Fairview, Henry Farm, Oriole              43.778517
# 56                       Fairview, Henry Farm, Oriole              43.778517
# 57                       Fairview, Henry Farm, Oriole              43.778517
# 58                       Fairview, Henry Farm, Oriole              43.778517
# 59                       Fairview, Henry Farm, Oriole              43.778517
# 60                       Fairview, Henry Farm, Oriole              43.778517
# 61                       Fairview, Henry Farm, Oriole              43.778517
# 62                       Fairview, Henry Farm, Oriole              43.778517
# 63                       Fairview, Henry Farm, Oriole              43.778517
# 68                                    Bayview Village              43.786947
# 69                                    Bayview Village              43.786947
# 72                                  Willowdale, South              43.770120
# 73                                  Willowdale, South              43.770120
# 74                                  Willowdale, South              43.770120
# 75                                  Willowdale, South              43.770120
# 76                                  Willowdale, South              43.770120
# 77                                  Willowdale, South              43.770120
#
#     Neighborhood Longitude                               Venue  \
# 0               -79.408493  Symposium Cafe Restaurant & Lounge
# 1               -79.543484                              Subway
# 6               -79.520999                          Wingporium
# 7               -79.520999                    South St. Burger
# 8               -79.520999                Artisano Bakery Café
# 9               -79.520999                              Subway
# 14              -79.577201                                LCBO
# 15              -79.577201                           Starbucks
# 16              -79.577201                      Cafe Sympatico
# 17              -79.577201                           Pizza Hut
# 19              -79.532242                           Starbucks
# 20              -79.532242                 Pizza Hut Etobicoke
# 21              -79.532242                              Subway
# 25              -79.588437           Popeyes Louisiana Kitchen
# 26              -79.588437                              Subway
# 27              -79.588437                         Pizza Pizza
# 28              -79.588437                         Tim Hortons
# 32              -79.615819               Quesada Mexican Grill
# 33              -79.615819                         Tim Hortons
# 34              -79.615819                              Subway
# 35              -79.615819                         Tim Hortons
# 36              -79.615819         Mary Brown's Famous Chicken
# 37              -79.615819                           Starbucks
# 45              -79.346556                    CF Fairview Mall
# 46              -79.346556               Moxie's Classic Grill
# 47              -79.346556                          SilverCity
# 48              -79.346556                  Purdys Chocolatier
# 49              -79.346556                   Michel's Baguette
# 50              -79.346556                       Booster Juice
# 51              -79.346556              Hero Certified Burgers
# 52              -79.346556                  Aroma Espresso Bar
# 53              -79.346556                           Starbucks
# 54              -79.346556            Fairview Library Theatre
# 55              -79.346556                  Ten Ren's Tea Time
# 56              -79.346556                         Tim Hortons
# 57              -79.346556                         Tim Hortons
# 58              -79.346556                         Heart Sushi
# 59              -79.346556                         Tim Hortons
# 60              -79.346556                                LCBO
# 61              -79.346556                        Spring Rolls
# 62              -79.346556               St. Louis Bar & Grill
# 63              -79.346556                              Z•teca
# 68              -79.385975       Sun Star Chinese Cuisine 翠景小炒
# 69              -79.385975         Maxim's Cafe and Patisserie
# 72              -79.408493                       Konjiki Ramen
# 73              -79.408493                           Starbucks
# 74              -79.408493                    Cineplex Cinemas
# 75              -79.408493                               Saryo
# 76              -79.408493                  Aroma Espresso Bar
# 77              -79.408493                         Dairy Queen
#
#     Venue Latitude  Venue Longitude       Venue Category SimpleCategory  \
# 0        43.771075       -79.413396           Restaurant      CheapMeal
# 1        43.599152       -79.544395       Sandwich Place      CheapMeal
# 6        43.630275       -79.518169          Wings Joint      CheapMeal
# 7        43.631314       -79.518408         Burger Joint      CheapMeal
# 8        43.631006       -79.518172               Bakery  CoffeeDessert
# 9        43.631659       -79.519001       Sandwich Place      CheapMeal
# 14       43.642099       -79.576592         Liquor Store            Bar
# 15       43.641312       -79.576924          Coffee Shop  CoffeeDessert
# 16       43.641820       -79.576721                 Café      CheapMeal
# 17       43.641514       -79.576326          Pizza Place    Ethnic Food
# 19       43.696338       -79.533398          Coffee Shop  CoffeeDessert
# 20       43.696562       -79.533506          Pizza Place    Ethnic Food
# 21       43.692927       -79.531471       Sandwich Place      CheapMeal
# 25       43.741209       -79.584332  Fried Chicken Joint      CheapMeal
# 26       43.742645       -79.589643       Sandwich Place      CheapMeal
# 27       43.741569       -79.584489          Pizza Place    Ethnic Food
# 28       43.742015       -79.589690          Coffee Shop  CoffeeDessert
# 32       43.636916       -79.620580        Burrito Place    Ethnic Food
# 33       43.635986       -79.616829          Coffee Shop  CoffeeDessert
# 34       43.636873       -79.620879       Sandwich Place      CheapMeal
# 35       43.635621       -79.621405          Coffee Shop  CoffeeDessert
# 36       43.636836       -79.620575  Fried Chicken Joint      CheapMeal
# 37       43.636960       -79.621030          Coffee Shop  CoffeeDessert
# 45       43.777981       -79.344397        Shopping Mall       FunStore
# 46       43.777779       -79.343185  American Restaurant    Ethnic Food
# 47       43.778681       -79.344085        Movie Theater  Entertainment
# 48       43.778160       -79.344154       Chocolate Shop  CoffeeDessert
# 49       43.777082       -79.344557               Bakery  CoffeeDessert
# 50       43.777428       -79.344970            Juice Bar  CoffeeDessert
# 51       43.777295       -79.344584         Burger Joint      CheapMeal
# 52       43.777700       -79.344652          Coffee Shop  CoffeeDessert
# 53       43.777990       -79.344091          Coffee Shop  CoffeeDessert
# 54       43.779018       -79.346526              Theater  Entertainment
# 55       43.777158       -79.344531            Juice Bar  CoffeeDessert
# 56       43.777964       -79.344715          Coffee Shop  CoffeeDessert
# 57       43.774993       -79.346303          Coffee Shop  CoffeeDessert
# 58       43.777203       -79.343805  Japanese Restaurant    Ethnic Food
# 59       43.775249       -79.347740          Coffee Shop  CoffeeDessert
# 60       43.778955       -79.345048         Liquor Store            Bar
# 61       43.777351       -79.343977     Asian Restaurant    Ethnic Food
# 62       43.777215       -79.345081                  Bar            Bar
# 63       43.777217       -79.344401        Burrito Place    Ethnic Food
# 68       43.787914       -79.381234   Chinese Restaurant    Ethnic Food
# 69       43.787863       -79.380751                 Café      CheapMeal
# 72       43.766998       -79.412222     Ramen Restaurant    Ethnic Food
# 73       43.768353       -79.413046          Coffee Shop  CoffeeDessert
# 74       43.768625       -79.412613        Movie Theater  Entertainment
# 75       43.766979       -79.412205                 Café      CheapMeal
# 76       43.769449       -79.413081                 Café      CheapMeal
# 77       43.767016       -79.412001       Ice Cream Shop  CoffeeDessert
#
#        City
# 0   Toronto
# 1   Toronto
# 6   Toronto
# 7   Toronto
# 8   Toronto
# 9   Toronto
# 14  Toronto
# 15  Toronto
# 16  Toronto
# 17  Toronto
# 19  Toronto
# 20  Toronto
# 21  Toronto
# 25  Toronto
# 26  Toronto
# 27  Toronto
# 28  Toronto
# 32  Toronto
# 33  Toronto
# 34  Toronto
# 35  Toronto
# 36  Toronto
# 37  Toronto
# 45  Toronto
# 46  Toronto
# 47  Toronto
# 48  Toronto
# 49  Toronto
# 50  Toronto
# 51  Toronto
# 52  Toronto
# 53  Toronto
# 54  Toronto
# 55  Toronto
# 56  Toronto
# 57  Toronto
# 58  Toronto
# 59  Toronto
# 60  Toronto
# 61  Toronto
# 62  Toronto
# 63  Toronto
# 68  Toronto
# 69  Toronto
# 72  Toronto
# 73  Toronto
# 74  Toronto
# 75  Toronto
# 76  Toronto
# 77  Toronto

# %% [markdown]
# <h2>Toronto map with Circle Markers based on Venue Simple Category</h2>

# %%
#-79.39868
map_toronto = folium.Map(location=[43.6550, -79.36], zoom_start=14,  
                         min_zoom=9, max_zoom=24)

# add markers to map
for lat, lng, rating, votesum, category, name in zip(tor_details['Venue Latitude'], 
                                           tor_details['Venue Longitude'], 
                                           tor_details['Rating'], 
                                           tor_details['VoteSum'],
                                           tor_details['SimpleCategory'],
                                           tor_details['Name']
                                              ):
    if rating < 6.0:
        ratcol = "#000000"
    elif (rating >= 6.0) & (rating < 7.0):
        ratcol = "#051094"
    elif (rating >= 7.0) & (rating < 8.0):
        ratcol = "#A32CC4"
    elif (rating >= 8.0) & (rating < 9.0):
        ratcol = "#BC544B"
    elif (rating >= 9.0) & (rating <= 10.0):
        ratcol = "#D21404"
        
    label = '{}:{}, Rating:{}, Votes:{}'.format(name,category, rating, votesum)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=4,
        popup=label,
        weight=4,
        color=ratcol,
        fill=True,
        fill_color=ratcol,
        fill_opacity=1,
        parse_html=False).add_to(map_toronto)  
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_bb37b5955d70422190be16caf7841d6f%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_bb37b5955d70422190be16caf7841d6f%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_bb37b5955d70422190be16caf7841d6f%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_bb37b5955d70422190be16caf7841d6f%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B43.655%2C%20-79.36%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %% [markdown]
# <h2>NYC map with Circle Markers based on Venue Simple Category</h2>

# %%
#40.741223327240284, -73.98972094611943
map_nyc = folium.Map(location=[40.741223327240284, -73.98972094611943], zoom_start=14,  
                         min_zoom=9, max_zoom=24)

# add markers to map
for lat, lng, rating, votesum, category, name in zip(nyc_details['Venue Latitude'], 
                                           nyc_details['Venue Longitude'], 
                                           nyc_details['Rating'], 
                                           nyc_details['VoteSum'],
                                           nyc_details['SimpleCategory'],
                                           nyc_details['Name']):
    if (rating < 3.0): 
        ratcol = "#000000"                                 
    elif (rating >= 3.0) & (rating < 6.0):
        ratcol = "#65350F"
    elif (rating >= 6.0) & (rating < 7.0):
        ratcol = "#051094"
    elif (rating >= 7.0) & (rating < 8.0):
        ratcol = "#A32CC4"
    elif (rating >= 8.0) & (rating < 9.0):
        ratcol = "#BC544B"
    elif (rating >= 9.0) & (rating <= 10.0):
        ratcol = "#D21404"
        
    label = '{}:{}, Rating:{}, Votes:{}'.format(name,category, rating, votesum)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=4,
        popup=label,
        weight=4,
        color=ratcol,
        fill=True,
        fill_color=ratcol,
        fill_opacity=1,
        parse_html=False).add_to(map_nyc)  
    
map_nyc
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_04ab6675980a4f0f8faed9d98aaf367e%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_04ab6675980a4f0f8faed9d98aaf367e%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_04ab6675980a4f0f8faed9d98aaf367e%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_04ab6675980a4f0f8faed9d98aaf367e%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B40.741223327240284%2C%20-73.98972094611943%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20% ...

# %% [markdown]
# <h2>NYC map with ICONS based on Venue Simple Category</h2>

# %%
#40.741223327240284, -73.98972094611943
map_nyc = folium.Map(location=[40.741223327240284, -73.98972094611943], zoom_start=12,  
                         min_zoom=9, max_zoom=24)

# add markers to map
for lat, lng, rating, votesum, category, name, neighborhood in zip(nyc_details['Venue Latitude'], 
                                           nyc_details['Venue Longitude'], 
                                           nyc_details['Rating'], 
                                           nyc_details['VoteSum'],
                                           nyc_details['SimpleCategory'],
                                           nyc_details['Name'],
                                           nyc_details['Neighborhood']):
    
    if (rating < 3.0): 
        ratcol = 'black'
    elif (rating >= 3.0) & (rating < 6.0):
        ratcol = 'gray'
    elif (rating >= 6.0) & (rating < 7.0):
        ratcol = 'lightblue'
    elif (rating >= 7.0) & (rating < 8.0):
        ratcol = 'blue'
    elif (rating >= 8.0) & (rating < 9.0):
        ratcol = 'lightred'
    elif (rating >= 9.0) & (rating <= 10.0):
        ratcol = 'red' 
    
    if category == "Bar":
        icontype="glass"
    elif category == "Ethnic Food":
        icontype="trophy"
    elif category == "CheapMeal":
        icontype = "star-half-empty"
    elif category == "Recreation":
        icontype = "child"
    elif category == "FunStore":
        icontype == "gift"
    elif category == "Fancy Food":
        icontype = "dollar"
    elif category == "CoffeeDessert":
        icontype = "birthday-cake"

        
    label = '{} - {}:{}, Rating:{}, Votes:{}'.format(neighborhood, name,category, rating, votesum)
    label = folium.Popup(label, parse_html=True)
    
    folium.Marker(
        location=[lat, lng], 
        popup=label,
        #icon=folium.Icon(color=ratcol,icon="fa-utensils", prefix='fa')).add_to(map_nyc)
        icon=folium.Icon(color=ratcol,icon=icontype, prefix='fa')).add_to(map_nyc)
    

    
map_nyc
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_abc54a9d838742e89728a4bfbe16258d%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_abc54a9d838742e89728a4bfbe16258d%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_abc54a9d838742e89728a4bfbe16258d%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_abc54a9d838742e89728a4bfbe16258d%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B40.741223327240284%2C%20-73.98972094611943%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20% ...

# %% [markdown]
# <h2>Toronto map with ICONS based on Venue Simple Category</h2>

# %%
icon_map_toronto = folium.Map(location=[43.6550, -79.38], zoom_start=15,  
                         min_zoom=9, max_zoom=24)

# add markers to map
for lat, lng, rating, votesum, category, name, neighborhood in zip(
                                           tor_details['Venue Latitude'], 
                                           tor_details['Venue Longitude'], 
                                           tor_details['Rating'], 
                                           tor_details['VoteSum'],
                                           tor_details['SimpleCategory'],
                                           tor_details['Name'],
                                           tor_details['Neighborhood']):
    
    # TEMP HACK
    if "Central Bay Street" not in neighborhood:
        continue
        
    # Colors avail:'gray', 'orange', 'cadetblue', 'beige', 'white', 'black', 'darkpurple', 'blue', 
    # 'lightgreen', 'darkgreen', 'lightred', 'pink', 'lightgray', 'green', 'darkred', 'darkblue', 'red', 'lightblue', 'purple'
    if (rating < 3.0): 
        ratcol = 'black' # "#000000"                                 
    elif (rating >= 3.0) & (rating < 6.0):
        ratcol = 'gray' # "#65350F"
    elif (rating >= 6.0) & (rating < 7.0):
        ratcol = 'lightblue' # "#051094"
    elif (rating >= 7.0) & (rating < 8.0):
        ratcol = 'blue' #  "#A32CC4"
    elif (rating >= 8.0) & (rating < 9.0):
        ratcol = 'lightred' # "#BC544B"
    elif (rating >= 9.0) & (rating <= 10.0):
        ratcol = 'red' #'red' #"#D21404"
    
    if category == "Bar":
        icontype="glass"
    elif category == "Ethnic Food":
        icontype="trophy"
    elif category == "CheapMeal":
        icontype = "star-half-empty"
    elif category == "Recreation":
        icontype = "child"
    elif category == "FunStore":
        icontype == "gift"
    elif category == "Fancy Food":
        icontype = "dollar"
    elif category == "CoffeeDessert":
        icontype = "birthday-cake"

        
    label = '{} - {}:{}, Rating:{}, Votes:{}'.format(neighborhood, name,category, rating, votesum)
    label = folium.Popup(label, parse_html=True)
    
    folium.Marker(
        location=[lat, lng], 
        popup=label,
        icon=folium.Icon(color=ratcol,icon=icontype, prefix='fa')).add_to(icon_map_toronto)
    

    
icon_map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_e347ebedc46740dea38f2ba81fbc0087%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_e347ebedc46740dea38f2ba81fbc0087%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_e347ebedc46740dea38f2ba81fbc0087%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_e347ebedc46740dea38f2ba81fbc0087%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B43.655%2C%20-79.38%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# <h2>This pickle file has everything I needed for Mapping, and I will use this now to generate some statistics</h2>

# %%
venues_with_details = pd.read_pickle("venues_with_details.pkl")

# %%
tor_details = venues_with_details[venues_with_details["City"]=="Toronto"]
nyc_details = venues_with_details[venues_with_details["City"]=="New York"]

# %% [markdown]
# <h2>Removing some Columns I don't Need</h2>

# %%
tor_details.head(20)
drop_these = ['Neighborhood Latitude', 'Neighborhood Longitude','Venue','Venue Latitude','Venue Longitude', 'Venue_Id']
tor_details.drop(drop_these, axis=1, inplace=True)
nyc_details.drop(drop_these, axis=1, inplace=True)
# Out:
# D:\Applications\Anaconda\lib\site-packages\pandas\core\frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
# Toronto Rating and PriceTier have NaN
# NYC so far has NO nulls in these columns
tor_details.fillna(value=0, inplace=True)
# Out:
# D:\Applications\Anaconda\lib\site-packages\pandas\core\frame.py:4317: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(

# %%
nyc_details[0:10]
# Out:
#                                                   Name  TipsCount  LikesCount  \
# 794                             El Pequeno Coffee Shop         14           9
# 795                                              Thaan          1           1
# 796                                      Casa Colombia          3           4
# 797                              La Gata Golosa Bakery          7           8
# 798  Eim Khao Mun Kai Elmhurst อิ่ม ข้าวมันไก่เอ็มเ...         26          99
# 799                                             Lamoon          9          35
# 800                    Louie's Pizzeria and Restaurant         26          63
# 801                                           La Fusta         34          55
# 802                    Taste Good Malaysian Cuisine 好味         55         119
# 803                         Five Loaves and Two Fishes          3           5
#
#      Rating  RatingSignals PriceTier  VoteSum     Neighborhood  \
# 794     6.1             23         2       55  Jackson Heights
# 795     0.0              0         2        3  Jackson Heights
# 796     5.8              9         2       20  Jackson Heights
# 797     5.6             17         1       40  Jackson Heights
# 798     8.7            128         1      352         Elmhurst
# 799     8.6             46         2      125         Elmhurst
# 800     9.1             91         1      243         Elmhurst
# 801     8.7             87         2      231         Elmhurst
# 802     8.3            170         1      463         Elmhurst
# 803     8.2             13         1       26         Elmhurst
#
#                 Venue Category SimpleCategory      City
# 794  Latin American Restaurant    Ethnic Food  New York
# 795            Thai Restaurant    Ethnic Food  New York
# 796  South American Restaurant    Ethnic Food  New York
# 797  South American Restaurant    Ethnic Food  New York
# 798            Thai Restaurant    Ethnic Food  New York
# 799            Thai Restaurant    Ethnic Food  New York
# 800                Pizza Place    Ethnic Food  New York
# 801     Argentinian Restaurant    Ethnic Food  New York
# 802           Malay Restaurant    Ethnic Food  New York
# 803         Chinese Restaurant    Ethnic Food  New York

# %%
topvenuedetails = pd.read_pickle("topvenuedetails.pkl")

# %%
tvd_groups = topvenuedetails.groupby(["City", "Neighborhood"])

# %%
tvd_group_stats = tvd_groups[["TipsCount","LikesCount","Rating","RatingSignals","PriceTier","VoteSum"]].mean()

# %%
tvd_group_stats = tvd_group_stats.reset_index()

# %%
tvd_group_stats = tvd_group_stats.sort_values(by="Rating", ascending=False,ignore_index=True)

# %% [markdown]
# <h1>Nearly all the most highly rated venues are in New York</h1>

# %%
tvd_group_stats.head(20)
# Out:
#         City                                       Neighborhood   TipsCount  \
# 0   New York                                       West Village  109.267442
# 1   New York                                       East Village  111.932584
# 2   New York                                         North Side   86.976744
# 3   New York                                         South Side   84.311111
# 4   New York                                 Financial District   50.156627
# 5   New York                                    Upper West Side   60.529412
# 6   New York                                          Yorkville   28.848837
# 7   New York                                           Downtown   30.192771
# 8   New York                                        Murray Hill   39.764228
# 9    Toronto                     Commerce Court, Victoria Hotel   24.448276
# 10  New York                                            Astoria   29.393258
# 11   Toronto             First Canadian Place, Underground city   23.471264
# 12   Toronto                           Richmond, Adelaide, King   30.168831
# 13   Toronto                                     St. James Town   34.096774
# 14   Toronto           Toronto Dominion Centre, Design Exchange   25.876543
# 15   Toronto                               Church and Wellesley   18.390625
# 16   Toronto   Stn A PO Boxes, 25 The Esplanade, Enclave of M5E   24.822785
# 17   Toronto  Harbourfront East, Union Station, Toronto Islands   31.200000
# 18   Toronto                           Garden District, Ryerson   43.641791
# 19   Toronto                                 Central Bay Street   22.803279
#
#     LikesCount    Rating  RatingSignals      VoteSum
# 0   350.162791  8.681395     511.302326  1320.895349
# 1   297.179775  8.643820     472.258427  1178.550562
# 2   319.790698  8.623256     446.569767  1173.127907
# 3   270.544444  8.485556     376.800000  1002.200000
# 4   195.048193  8.416867     264.036145   704.289157
# 5   174.494118  8.247059     262.094118   671.611765
# 6    76.581395  8.096512     121.255814   303.267442
# 7   119.096386  8.068675     167.855422   436.240964
# 8   123.691057  8.021138     182.105691   469.252033
# 9    74.057471  7.970115     105.528736   278.091954
# 10   56.191011  7.966292      99.516854   241.292135
# 11   77.080460  7.959770     106.850575   284.482759
# 12   96.792208  7.958442     135.831169   359.584416
# 13   89.645161  7.885484     132.209677   345.596774
# 14  104.530864  7.841975     142.246914   377.185185
# 15   43.484375  7.821875      66.671875   172.031250
# 16   90.012658  7.808861     124.227848   329.075949
# 17  150.235294  7.735294     202.729412   534.400000
# 18  145.671642  7.725373     207.134328   542.119403
# 19   49.786885  7.114754      80.327869   202.704918

# %%
# tvd_group_stats['Rating'].corr(tvd_group_stats['RatingSignals']) #0.831783606731402
# tvd_group_stats['Rating'].corr(tvd_group_stats['LikesCount']) #0.8276978097445825
nyc_stats = tvd_group_stats[tvd_group_stats['City']=='New York'] #['Rating'].corr(tvd_group_stats['LikesCount'])
tor_stats = tvd_group_stats[tvd_group_stats['City']=='Toronto']

# %% [markdown]
# <h2>When we adjust Toronto's venue "votes" to consider it's population, it has more than NYC</h2>

# %%
print('Mean NYC Rating: ' + str(nyc_stats['Rating'].mean()))
print('Mean NYC Votes: ' + str(nyc_stats['VoteSum'].mean()))
print('Mean Toronto Rating: ' + str(tor_stats['Rating'].mean()))
print('Mean Toronto Votes: ' + str(tor_stats['VoteSum'].mean()))
print('Mean Toronto Votes (Adusted for Population): ' + str(tor_stats['VoteSum'].mean() * 2.98) )
# Out:
# Mean NYC Rating: 8.325056990939
# Mean NYC Votes: 750.0727312011767
# Mean Toronto Rating: 7.782194290535228
# Mean Toronto Votes: 342.5272607991777
# Mean Toronto Votes (Adusted for Population): 1020.7312371815497

# %%
# NYC Population 8,804,190 as of April 1, 2020
# TOR Population 2,956,024
# NYC is 2.98 times larger

# %%
topvenuedetails.head()
# Out:
#                     Venue_Id            Name  TipsCount  LikesCount  Rating  \
# 87  52138db911d22803b334c641  Mos Mos Coffee         11          54     8.5
# 88  52138db911d22803b334c641  Mos Mos Coffee         11          54     8.5
# 89  52138db911d22803b334c641  Mos Mos Coffee         11          54     8.5
# 90  52138db911d22803b334c641  Mos Mos Coffee         11          54     8.5
# 91  52138db911d22803b334c641  Mos Mos Coffee         11          54     8.5
#
#     RatingSignals PriceTier  VoteSum  \
# 87             69         1      188
# 88             69         1      188
# 89             69         1      188
# 90             69         1      188
# 91             69         1      188
#
#                                         Neighborhood  Neighborhood Latitude  \
# 87                                    St. James Town              43.651494
# 88          Toronto Dominion Centre, Design Exchange              43.647177
# 89                    Commerce Court, Victoria Hotel              43.648198
# 90  Stn A PO Boxes, 25 The Esplanade, Enclave of M5E              43.646435
# 91            First Canadian Place, Underground city              43.648429
#
#     Neighborhood Longitude           Venue  Venue Latitude  Venue Longitude  \
# 87              -79.375418  Mos Mos Coffee       43.648159       -79.378745
# 88              -79.381576  Mos Mos Coffee       43.648159       -79.378745
# 89              -79.379817  Mos Mos Coffee       43.648159       -79.378745
# 90              -79.374846  Mos Mos Coffee       43.648159       -79.378745
# 91              -79.382280  Mos Mos Coffee       43.648159       -79.378745
#
#    Venue Category SimpleCategory     City
# 87           Café      CheapMeal  Toronto
# 88           Café      CheapMeal  Toronto
# 89           Café      CheapMeal  Toronto
# 90           Café      CheapMeal  Toronto
# 91           Café      CheapMeal  Toronto

# %%
nyc_counts = topvenuedetails[topvenuedetails["City"] == "New York"]
nyc_counts = nyc_counts[["Neighborhood","SimpleCategory"]]
# Out:
#          Neighborhood SimpleCategory
# 1204  Upper West Side  Entertainment
# 1205  Upper West Side    Ethnic Food
# 1206  Upper West Side  Entertainment
# 1207  Upper West Side     Fancy Food
# 1208  Upper West Side    Ethnic Food

# %%
# Get distinct combinations of neighborhood and city - looks like some city data is wrong
neigh_city = topvenuedetails[["City", "Neighborhood", "SimpleCategory"]]#.sort_values(by=['City','Neighborhood','SimpleCategory'], inplace=True)
neigh_values = neigh_city.value_counts()

# %% [markdown]
# <h1>Looking at each neighborhood, and how many venues it has by category</h1>

# %%
#neigh_values[neigh_values["City"]=='New York']
#data.groupby('month')['duration'].sum()
pd.set_option('display.max_rows', 500)
neigh_city.groupby(['City','Neighborhood','SimpleCategory'])['SimpleCategory'].count()
# Out:
# City      Neighborhood                                       SimpleCategory
# New York  Astoria                                            Bar               14
#                                                              CheapMeal         13
#                                                              CoffeeDessert     13
#                                                              Ethnic Food       38
#                                                              Fancy Food         4
#                                                              Recreation         7
#           Downtown                                           Bar                7
#                                                              CheapMeal         13
#                                                              CoffeeDessert     11
#                                                              Entertainment      4
#                                                              Ethnic Food       28
#                                                              Fancy Food         4
#                                                              FunStore           5
#                                                              Recreation        11
#           East Village                                       Bar               20
#                                                              CheapMeal          7
#                                                              CoffeeDessert     11
#                                                              Entertainment      2
#                                                              Ethnic Food       40
#                                                              Fancy Food         1
#                                                              FunStore           5
#                                                              Recreation         3
#           Financial District                                 Bar                8
#                                                              CheapMeal         11
#                                                              CoffeeDessert     16
#                                                              Entertainment      4
#                                                              Ethnic Food       22
#                                                              Entertainment      1
#                                                              Ethnic Food       20
#                                                              Fancy Food         6
#                                                              FunStore           2
#                                                              Recreation         5
#           Stn A PO Boxes, 25 The Esplanade, Enclave of M5E   Bar               11
#                                                              CheapMeal         11
#                                                              CoffeeDessert     15
#                                                              Entertainment      5
#                                                              Ethnic Food       18
#                                                              Fancy Food         7
#                                                              FunStore           5
#                                                              Recreation         7
#           Toronto Dominion Centre, Design Exchange           Bar               10
#                                                              CheapMeal         16
#                                                              CoffeeDessert     16
#                                                              Entertainment      6
#                                                              Ethnic Food       21
#                                                              Fancy Food         7
#                                                              FunStore           2
#                                                              Recreation         3
# Name: SimpleCategory, dtype: int64

# %%
neigh_city.groupby(['SimpleCategory','City','Neighborhood'])['SimpleCategory'].count()
# Out:
# SimpleCategory  City      Neighborhood
# Bar             New York  Astoria                                              14
#                           Downtown                                              7
#                           East Village                                         20
#                           Financial District                                    8
#                           Murray Hill                                          11
#                           North Side                                           17
#                           South Side                                           22
#                           Upper West Side                                      13
#                           West Village                                         15
#                           Yorkville                                             9
#                 Toronto   Central Bay Street                                    2
#                           Church and Wellesley                                  9
#                           Commerce Court, Victoria Hotel                        8
#                           First Canadian Place, Underground city                9
#                           Garden District, Ryerson                              4
#                           Harbourfront East, Union Station, Toronto Islands    10
#                           Richmond, Adelaide, King                              8
#                           St. James Town                                       10
#                           Stn A PO Boxes, 25 The Esplanade, Enclave of M5E     11
#                           Toronto Dominion Centre, Design Exchange             10
# CheapMeal       New York  Astoria                                              13
#                           Downtown                                             13
#                           East Village                                          7
#                           Financial District                                   11
#                           Murray Hill                                          19
#                           North Side                                            7
#                           South Side                                           10
#                           Upper West Side                                      11
#                           West Village                                          4
#                           Yorkville                                            13
#                 Toronto   Central Bay Street                                   13
#                           Church and Wellesley                                  7
#                           Commerce Court, Victoria Hotel                       22
#                           First Canadian Place, Underground city               18
#                           Garden District, Ryerson                              6
#                           Harbourfront East, Union Station, Toronto Islands    12
#                           Richmond, Adelaide, King                             13
#                           St. James Town                                       10
#                           Stn A PO Boxes, 25 The Esplanade, Enclave of M5E     11
#                           Toronto Dominion Centre, Design Exchange             16
# CoffeeDessert   New York  Astoria                                              13
#                           Downtown                                             11
#                           East Village                                         11
#                           Financial District                                   16
#                           Murray Hill                                          14
#                           North Side                                           21
#                           South Side                                            9
#                           Upper West Side                                      12
#                           West Village                                         10
#                           Yorkville                                            12
#                 Toronto   Central Bay Street                                   19
#                           Church and Wellesley                                  9
#                           Commerce Court, Victoria Hotel                       17
#                           First Canadian Place, Underground city               14
#                           Garden District, Ryerson                             16
#                           Harbourfront East, Union Station, Toronto Islands    20
#                           Richmond, Adelaide, King                             12
#                           St. James Town                                        8
#                           Stn A PO Boxes, 25 The Esplanade, Enclave of M5E     15
#                           Toronto Dominion Centre, Design Exchange             16
# Entertainment   New York  Downtown                                              4
#                           East Village                                          2
#                           Financial District                                    4
#                           Murray Hill                                           2
#                           North Side                                            2
#                           South Side                                            2
#                           Upper West Side                                       3
#                           West Village                                          6
#                           Yorkville                                             1
#                 Toronto   Central Bay Street                                    1
#                           Church and Wellesley                                  2
#                           Commerce Court, Victoria Hotel                        2
#                           First Canadian Place, Underground city                5
#                           Garden District, Ryerson                              4
#                           Harbourfront East, Union Station, Toronto Islands    15
#                           Richmond, Adelaide, King                              5
#                           St. James Town                                        1
#                           Stn A PO Boxes, 25 The Esplanade, Enclave of M5E      5
#                           Toronto Dominion Centre, Design Exchange              6
# Ethnic Food     New York  Astoria                                              38
#                           Downtown                                             28
#                           East Village                                         40
#                           Financial District                                   22
#                           Murray Hill                                          59
#                           North Side                                           29
#                           South Side                                           35
#                           Upper West Side                                      36
#                           West Village                                         29
#                           Yorkville                                            30
#                 Toronto   Central Bay Street                                   17
#                           Church and Wellesley                                 25
#                           Commerce Court, Victoria Hotel                       20
#                           First Canadian Place, Underground city               26
#                           Garden District, Ryerson                             21
#                           Harbourfront East, Union Station, Toronto Islands    12
#                           Richmond, Adelaide, King                             26
#                           St. James Town                                       20
#                           Stn A PO Boxes, 25 The Esplanade, Enclave of M5E     18
#                           Toronto Dominion Centre, Design Exchange             21
# Fancy Food      New York  Astoria                                               4
#                           Downtown                                              4
#                           East Village                                          1
#                           Financial District                                    6
#                           Murray Hill                                           5
#                           North Side                                            2
#                           South Side                                            3
#                           Upper West Side                                       4
#                           West Village                                          8
#                           Yorkville                                             3
#                 Toronto   Central Bay Street                                    3
#                           Church and Wellesley                                  1
#                           Commerce Court, Victoria Hotel                        6
#                           First Canadian Place, Underground city                7
#                           Garden District, Ryerson                              3
#                           Harbourfront East, Union Station, Toronto Islands     4
#                           Richmond, Adelaide, King                              4
#                           St. James Town                                        6
#                           Stn A PO Boxes, 25 The Esplanade, Enclave of M5E      7
#                           Toronto Dominion Centre, Design Exchange              7
# FunStore        New York  Downtown                                              5
#                           East Village                                          5
#                           North Side                                            2
#                           South Side                                            1
#                           Upper West Side                                       2
#                           West Village                                          2
#                           Yorkville                                             1
#                 Toronto   Central Bay Street                                    1
#                           Church and Wellesley                                  1
#                           Commerce Court, Victoria Hotel                        3
#                           First Canadian Place, Underground city                2
#                           Garden District, Ryerson                              5
#                           Harbourfront East, Union Station, Toronto Islands     1
#                           Richmond, Adelaide, King                              3
#                           St. James Town                                        2
#                           Stn A PO Boxes, 25 The Esplanade, Enclave of M5E      5
#                           Toronto Dominion Centre, Design Exchange              2
# Recreation      New York  Astoria                                               7
#                           Downtown                                             11
#                           East Village                                          3
#                           Financial District                                   16
#                           Murray Hill                                          13
#                           North Side                                            6
#                           South Side                                            8
#                           Upper West Side                                       4
#                           West Village                                         12
#                           Yorkville                                            17
#                 Toronto   Central Bay Street                                    5
#                           Church and Wellesley                                 10
#                           Commerce Court, Victoria Hotel                        9
#                           First Canadian Place, Underground city                6
#                           Garden District, Ryerson                              8
#                           Harbourfront East, Union Station, Toronto Islands    11
#                           Richmond, Adelaide, King                              6
#                           St. James Town                                        5
#                           Stn A PO Boxes, 25 The Esplanade, Enclave of M5E      7
#                           Toronto Dominion Centre, Design Exchange              3
# Name: SimpleCategory, dtype: int64

# %%
neigh_city.groupby(['SimpleCategory','City'])['SimpleCategory'].count() \
    .reset_index(name='count') \
    .sort_values(['count'], ascending=False) \
    .head(40)
# Out:
#    SimpleCategory      City  count
# 8     Ethnic Food  New York    346
# 9     Ethnic Food   Toronto    206
# 5   CoffeeDessert   Toronto    146
# 0             Bar  New York    136
# 4   CoffeeDessert  New York    129
# 3       CheapMeal   Toronto    128
# 2       CheapMeal  New York    108
# 14     Recreation  New York     97
# 1             Bar   Toronto     81
# 15     Recreation   Toronto     70
# 11     Fancy Food   Toronto     48
# 7   Entertainment   Toronto     46
# 10     Fancy Food  New York     40
# 6   Entertainment  New York     26
# 13       FunStore   Toronto     25
# 12       FunStore  New York     18

# %%
neigh_city.groupby(['SimpleCategory','City','Neighborhood'])['SimpleCategory'].count() \
    .reset_index(name='count') \
    .sort_values(['count'], ascending=False) \
    .head(40)
# Out:
#     SimpleCategory      City  \
# 83     Ethnic Food  New York
# 81     Ethnic Food  New York
# 79     Ethnic Food  New York
# 86     Ethnic Food  New York
# 85     Ethnic Food  New York
# 88     Ethnic Food  New York
# 84     Ethnic Food  New York
# 87     Ethnic Food  New York
# 80     Ethnic Food  New York
# 95     Ethnic Food   Toronto
# 92     Ethnic Food   Toronto
# 90     Ethnic Food   Toronto
# 82     Ethnic Food  New York
# 32       CheapMeal   Toronto
# 6              Bar  New York
# 45   CoffeeDessert  New York
# 98     Ethnic Food   Toronto
# 93     Ethnic Food   Toronto
# 2              Bar  New York
# 96     Ethnic Food   Toronto
# 91     Ethnic Food   Toronto
# 55   CoffeeDessert   Toronto
# 50   CoffeeDessert   Toronto
# 24       CheapMeal  New York
# 33       CheapMeal   Toronto
# 97     Ethnic Food   Toronto
# 89     Ethnic Food   Toronto
# 5              Bar  New York
# 52   CoffeeDessert   Toronto
# 145     Recreation  New York
# 54   CoffeeDessert   Toronto
# 59   CoffeeDessert   Toronto
# 139     Recreation  New York
# 43   CoffeeDessert  New York
# 39       CheapMeal   Toronto
# 58   CoffeeDessert   Toronto
# 74   Entertainment   Toronto
# 8              Bar  New York
# 53   CoffeeDessert   Toronto
# 44   CoffeeDessert  New York
#
#                                           Neighborhood  count
# 83                                         Murray Hill     59
# 81                                        East Village     40
# 79                                             Astoria     38
# 86                                     Upper West Side     36
# 85                                          South Side     35
# 88                                           Yorkville     30
# 84                                          North Side     29
# 87                                        West Village     29
# 80                                            Downtown     28
# 95                            Richmond, Adelaide, King     26
# 92              First Canadian Place, Underground city     26
# 90                                Church and Wellesley     25
# 82                                  Financial District     22
# 32                      Commerce Court, Victoria Hotel     22
# 6                                           South Side     22
# 45                                          North Side     21
# 98            Toronto Dominion Centre, Design Exchange     21
# 93                            Garden District, Ryerson     21
# 2                                         East Village     20
# 96                                      St. James Town     20
# 91                      Commerce Court, Victoria Hotel     20
# 55   Harbourfront East, Union Station, Toronto Islands     20
# 50                                  Central Bay Street     19
# 24                                         Murray Hill     19
# 33              First Canadian Place, Underground city     18
# 97    Stn A PO Boxes, 25 The Esplanade, Enclave of M5E     18
# 89                                  Central Bay Street     17
# 5                                           North Side     17
# 52                      Commerce Court, Victoria Hotel     17
# 145                                          Yorkville     17
# 54                            Garden District, Ryerson     16
# 59            Toronto Dominion Centre, Design Exchange     16
# 139                                 Financial District     16
# 43                                  Financial District     16
# 39            Toronto Dominion Centre, Design Exchange     16
# 58    Stn A PO Boxes, 25 The Esplanade, Enclave of M5E     15
# 74   Harbourfront East, Union Station, Toronto Islands     15
# 8                                         West Village     15
# 53              First Canadian Place, Underground city     14
# 44                                         Murray Hill     14

# %% [markdown]
# <h1>Average Rating By Neighborhood</h1>

# %%
neigh_rating = topvenuedetails[["City", "Neighborhood", "Rating"]]
neigh_rating.groupby(['City','Neighborhood'])['Rating'].mean() \
    .reset_index(name='mean') \
    .sort_values(['mean'], ascending=False) \
    .head(40)
# Out:
#         City                                       Neighborhood      mean
# 8   New York                                       West Village  8.681395
# 2   New York                                       East Village  8.643820
# 5   New York                                         North Side  8.623256
# 6   New York                                         South Side  8.485556
# 3   New York                                 Financial District  8.416867
# 7   New York                                    Upper West Side  8.247059
# 9   New York                                          Yorkville  8.096512
# 1   New York                                           Downtown  8.068675
# 4   New York                                        Murray Hill  8.021138
# 12   Toronto                     Commerce Court, Victoria Hotel  7.970115
# 0   New York                                            Astoria  7.966292
# 13   Toronto             First Canadian Place, Underground city  7.959770
# 16   Toronto                           Richmond, Adelaide, King  7.958442
# 17   Toronto                                     St. James Town  7.885484
# 19   Toronto           Toronto Dominion Centre, Design Exchange  7.841975
# 11   Toronto                               Church and Wellesley  7.821875
# 18   Toronto   Stn A PO Boxes, 25 The Esplanade, Enclave of M5E  7.808861
# 15   Toronto  Harbourfront East, Union Station, Toronto Islands  7.735294
# 14   Toronto                           Garden District, Ryerson  7.725373
# 10   Toronto                                 Central Bay Street  7.114754

# %%
neigh_diversity = topvenuedetails[["City", "Neighborhood", "SimpleCategory", "Venue Category"]]
diversity = neigh_diversity.groupby(['City','Neighborhood', "SimpleCategory"])['Venue Category'] \
    .apply(lambda x: len(np.unique(x))).to_frame()

# %%
diversity.reset_index(inplace=True)

# %%
diversity.sort_values(by="Venue Category", ascending=False)
# Out:
#          City                                       Neighborhood  \
# 56   New York                                    Upper West Side
# 33   New York                                        Murray Hill
# 10   New York                                           Downtown
# 18   New York                                       East Village
# 3    New York                                            Astoria
# 48   New York                                         South Side
# 128   Toronto                           Richmond, Adelaide, King
# 40   New York                                         North Side
# 88    Toronto                               Church and Wellesley
# 136   Toronto                                     St. James Town
# 104   Toronto             First Canadian Place, Underground city
# 112   Toronto                           Garden District, Ryerson
# 64   New York                                       West Village
# 80    Toronto                                 Central Bay Street
# 96    Toronto                     Commerce Court, Victoria Hotel
# 72   New York                                          Yorkville
# 144   Toronto   Stn A PO Boxes, 25 The Esplanade, Enclave of M5E
# 152   Toronto           Toronto Dominion Centre, Design Exchange
# 26   New York                                 Financial District
# 44   New York                                         South Side
# 23   New York                                 Financial District
# 120   Toronto  Harbourfront East, Union Station, Toronto Islands
# 75   New York                                          Yorkville
# 13   New York                                           Downtown
# 61   New York                                       West Village
# 83    Toronto                                 Central Bay Street
# 65   New York                                       West Village
# 77    Toronto                                 Central Bay Street
# 59   New York                                    Upper West Side
# 22   New York                                 Financial District
# 81    Toronto                                 Central Bay Street
# 129   Toronto                           Richmond, Adelaide, King
# 131   Toronto                           Richmond, Adelaide, King
# 98    Toronto                     Commerce Court, Victoria Hotel
# 21   New York                                       East Village
# 139   Toronto                                     St. James Town
# 142   Toronto   Stn A PO Boxes, 25 The Esplanade, Enclave of M5E
# 11   New York                                           Downtown
# 9    New York                                           Downtown
# 73   New York                                          Yorkville
# 150   Toronto           Toronto Dominion Centre, Design Exchange
# 63   New York                                       West Village
# 155   Toronto           Toronto Dominion Centre, Design Exchange
# 55   New York                                    Upper West Side
# 107   Toronto             First Canadian Place, Underground city
# 49   New York                                         South Side
# 102   Toronto             First Canadian Place, Underground city
# 94    Toronto                     Commerce Court, Victoria Hotel
# 111   Toronto                           Garden District, Ryerson
# 113   Toronto                           Garden District, Ryerson
# 105   Toronto             First Canadian Place, Underground city
# 106   Toronto             First Canadian Place, Underground city
# 138   Toronto                                     St. James Town
# 17   New York                                       East Village
# 76    Toronto                                 Central Bay Street
# 57   New York                                    Upper West Side
# 47   New York                                         South Side
# 66   New York                                       West Village
# 154   Toronto           Toronto Dominion Centre, Design Exchange
# 32   New York                                        Murray Hill
# 87    Toronto                               Church and Wellesley
# 58   New York                                    Upper West Side
# 130   Toronto                           Richmond, Adelaide, King
# 95    Toronto                     Commerce Court, Victoria Hotel
# 134   Toronto                                     St. James Town
# 25   New York                                 Financial District
# 42   New York                                         North Side
# 41   New York                                         North Side
# 135   Toronto                                     St. James Town
# 50   New York                                         South Side
# 39   New York                                         North Side
# 71   New York                                          Yorkville
# 4    New York                                            Astoria
# 122   Toronto  Harbourfront East, Union Station, Toronto Islands
# 74   New York                                          Yorkville
# 89    Toronto                               Church and Wellesley
# 90    Toronto                               Church and Wellesley
# 19   New York                                       East Village
# 79    Toronto                                 Central Bay Street
# 82    Toronto                                 Central Bay Street
#
#     SimpleCategory  Venue Category
# 56     Ethnic Food              23
# 33     Ethnic Food              23
# 10     Ethnic Food              22
# 18     Ethnic Food              22
# 3      Ethnic Food              22
# 48     Ethnic Food              21
# 128    Ethnic Food              18
# 40     Ethnic Food              17
# 88     Ethnic Food              15
# 136    Ethnic Food              15
# 104    Ethnic Food              14
# 112    Ethnic Food              14
# 64     Ethnic Food              13
# 80     Ethnic Food              13
# 96     Ethnic Food              13
# 72     Ethnic Food              13
# 144    Ethnic Food              12
# 152    Ethnic Food              12
# 26     Ethnic Food              11
# 44             Bar              11
# 23       CheapMeal              10
# 120    Ethnic Food              10
# 75      Recreation              10
# 13      Recreation               9
# 91      Recreation               9
# 60             Bar               9
# 35      Recreation               9
# 30       CheapMeal               9
# 67      Recreation               9
# 45       CheapMeal               8
# 115     Recreation               8
# 36             Bar               8
# 69       CheapMeal               8
# 119  Entertainment               8
# 123     Recreation               8
# 28      Recreation               8
# 149      CheapMeal               7
# 100            Bar               7
# 101      CheapMeal               7
# 141      CheapMeal               7
# 93       CheapMeal               7
# 78   CoffeeDessert               7
# 7        CheapMeal               7
# 1        CheapMeal               7
# 118  CoffeeDessert               7
# 148            Bar               7
# 52             Bar               6
# 92             Bar               6
# 15       CheapMeal               6
# 6              Bar               6
# 99      Recreation               6
# 2    CoffeeDessert               6
# 31   CoffeeDessert               6
# 16   CoffeeDessert               6
# 140            Bar               6
# 132            Bar               6
# 116            Bar               6
# 38   CoffeeDessert               6
# 51      Recreation               6
# 110  CoffeeDessert               5
# 143  Entertainment               5
# 137     Fancy Food               5
# 147     Recreation               5
# 125      CheapMeal               5
# 84             Bar               5
# 124            Bar               5
# 117      CheapMeal               5
# 151  Entertainment               5
# 0              Bar               5
# 68             Bar               5
# 14             Bar               5
# 37       CheapMeal               5
# 29             Bar               5
# 24   CoffeeDessert               5
# 62   CoffeeDessert               5
# 54   CoffeeDessert               5
# 8    CoffeeDessert               5
# 5       Recreation               5
# 12        FunStore               4
# 153     Fancy Food               4
# 53       CheapMeal               4
# 103  Entertainment               4
# 108            Bar               4
# 109      CheapMeal               4
# 46   CoffeeDessert               4
# 70   CoffeeDessert               4
# 114       FunStore               4
# 121     Fancy Food               4
# 34      Fancy Food               4
# 145     Fancy Food               4
# 27      Fancy Food               4
# 97      Fancy Food               4
# 127  Entertainment               4
# 146       FunStore               4
# 133      CheapMeal               4
# 20        FunStore               4
# 126  CoffeeDessert               4
# 43      Recreation               4
# 86   CoffeeDessert               4
# 85       CheapMeal               4
# 61       CheapMeal               4
# 83      Recreation               4
# 65      Fancy Food               4
# 77       CheapMeal               4
# 59      Recreation               4
# 22             Bar               3
# 81      Fancy Food               3
# 129     Fancy Food               3
# 131     Recreation               3
# 98        FunStore               3
# 21      Recreation               3
# 139     Recreation               3
# 142  CoffeeDessert               3
# 11      Fancy Food               3
# 9    Entertainment               3
# 73      Fancy Food               3
# 150  CoffeeDessert               3
# 63   Entertainment               3
# 155     Recreation               3
# 55   Entertainment               3
# 107     Recreation               3
# 49      Fancy Food               3
# 102  CoffeeDessert               3
# 94   CoffeeDessert               3
# 111  Entertainment               3
# 113     Fancy Food               3
# 105     Fancy Food               3
# 106       FunStore               2
# 138       FunStore               2
# 17   Entertainment               2
# 76             Bar               2
# 57      Fancy Food               2
# 47   Entertainment               2
# 66        FunStore               2
# 154       FunStore               2
# 32   Entertainment               2
# 87   Entertainment               2
# 58        FunStore               2
# 130       FunStore               2
# 95   Entertainment               2
# 134  CoffeeDessert               2
# 25   Entertainment               2
# 42        FunStore               2
# 41      Fancy Food               2
# 135  Entertainment               1
# 50        FunStore               1
# 39   Entertainment               1
# 71   Entertainment               1
# 4       Fancy Food               1
# 122       FunStore               1
# 74        FunStore               1
# 89      Fancy Food               1
# 90        FunStore               1
# 19      Fancy Food               1
# 79   Entertainment               1
# 82        FunStore               1

# %% [markdown]
# ### Importing Needed packages

# %%
import matplotlib.pyplot as plt
import pandas as pd
import pylab as pl
import numpy as np
# %matplotlib inline

# %% [markdown]
# ### Loading data, and filtering out data with venues but in wrong neighborhoods

# %%
venues_with_details = pd.read_pickle("venues_with_details.pkl")
core_df = venues_with_details[['City','Neighborhood', 'SimpleCategory','TipsCount', 'LikesCount', 'Rating', 'PriceTier']]
nyc_neighs = ['Astoria','Downtown ','East Village','Financial District','Murray Hill','North Side','South Side','Upper West Side','West Village','Yorkville']
tor_neighs = ['Central Bay Street','Church and Wellesley','Commerce Court, Victoria Hotel','First Canadian Place, Underground city','Garden District, Ryerson','Harbourfront East, Union Station, Toronto Islands','Richmond, Adelaide, King','St. James Town','Stn A PO Boxes, 25 The Esplanade, Enclave of M5E','Toronto Dominion Centre, Design Exchange']
core_df = core_df[((core_df['City']=='New York') \
                 & (core_df['Neighborhood'].isin(nyc_neighs))) \
                 | ((core_df['City']=='Toronto') \
                 & (core_df['Neighborhood'].isin(tor_neighs))) ]

# %% [markdown]
# ### Create filters for PriceTiers

# %%
# Filter out data where PriceTier or Rating are na
# use tilde in front of filter to negate this
yes_price_tier_filt = (core_df['Rating'].isnull()==False) & (core_df['PriceTier'].isnull()==False) & (core_df['PriceTier'] > 0)
no_price_tier_filt = (core_df['Rating'].isnull()==False) & ((core_df['PriceTier'].isnull()==True) | (core_df['PriceTier'] == 0))

price_df = core_df[yes_price_tier_filt]
no_price_df = core_df[no_price_tier_filt]

# %% [markdown]
# ### Do we have any nulls? We know we have them for no_price_df

# %%
price_df[price_df.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [City, Neighborhood, SimpleCategory, TipsCount, LikesCount, Rating, PriceTier]
# Index: []

# %%
no_price_df[no_price_df.isna().any(axis=1)]
# 88 Prices we want to predict
# Out:
#         City                                      Neighborhood SimpleCategory  \
# 97   Toronto                                    St. James Town       FunStore
# 99   Toronto  Stn A PO Boxes, 25 The Esplanade, Enclave of M5E       FunStore
# 104  Toronto          Toronto Dominion Centre, Design Exchange  Entertainment
# 105  Toronto  Stn A PO Boxes, 25 The Esplanade, Enclave of M5E  Entertainment
# 112  Toronto                    Commerce Court, Victoria Hotel     Recreation
# ..       ...                                               ...            ...
# 677  Toronto          Toronto Dominion Centre, Design Exchange      CheapMeal
# 678  Toronto            First Canadian Place, Underground city      CheapMeal
# 682  Toronto          Toronto Dominion Centre, Design Exchange  Entertainment
# 687  Toronto                          Garden District, Ryerson  CoffeeDessert
# 688  Toronto                                Central Bay Street  CoffeeDessert
#
#      TipsCount  LikesCount  Rating PriceTier
# 97           3          19     8.4       NaN
# 99           3          19     8.4       NaN
# 104         44         264     7.5       NaN
# 105         44         264     7.5       NaN
# 112          5           7     8.0       NaN
# ..         ...         ...     ...       ...
# 677         15          70     7.6       NaN
# 678         15          70     7.6       NaN
# 682          0           5     6.8       NaN
# 687          2           7     6.9       NaN
# 688          2           7     6.9       NaN
#
# [88 rows x 7 columns]

# %% [markdown]
# ### Create one-hot encoding for neighborhoods

# %%
# Since dummies will prefix the column name, shorten string by changing the name to "Cat"
core_df.rename(columns={'SimpleCategory':'Cat'}, inplace=True)

# %%
dummies_df = pd.get_dummies(core_df, columns=['City','Neighborhood','Cat'], drop_first=True)

# %%
price_df = dummies_df[yes_price_tier_filt]
no_price_df = dummies_df[no_price_tier_filt]

# %% [markdown]
# ### Lists of columns for multiple linear regression

# %%
# Do not include 'PriceTier'
columns = ['TipsCount','LikesCount','Rating','City_Toronto','Neighborhood_Central Bay Street','Neighborhood_Church and Wellesley','Neighborhood_Commerce Court, Victoria Hotel','Neighborhood_East Village','Neighborhood_Financial District','Neighborhood_First Canadian Place, Underground city','Neighborhood_Garden District, Ryerson','Neighborhood_Harbourfront East, Union Station, Toronto Islands','Neighborhood_Murray Hill','Neighborhood_North Side','Neighborhood_Richmond, Adelaide, King','Neighborhood_South Side','Neighborhood_St. James Town','Neighborhood_Stn A PO Boxes, 25 The Esplanade, Enclave of M5E','Neighborhood_Toronto Dominion Centre, Design Exchange','Neighborhood_Upper West Side','Neighborhood_West Village','Neighborhood_Yorkville','Cat_CheapMeal','Cat_CoffeeDessert','Cat_Entertainment','Cat_Ethnic Food','Cat_Fancy Food','Cat_FunStore','Cat_Recreation']

# %%
from sklearn import linear_model

# %%
regr = linear_model.LinearRegression()
x = np.asanyarray(price_df[columns])
y = np.asanyarray(price_df[['PriceTier']])
regr.fit (x, y)
# The coefficients
print ('Coefficients: ', regr.coef_)
# Out:
# Coefficients:  [[ 6.75136551e-04  2.41308131e-04  7.75082510e-02  3.00759356e-01
#    7.39359050e-02 -1.13685256e-03  1.39490743e-01  8.52406156e-02
#    4.27930889e-01  4.01063812e-02 -2.88683758e-01 -2.81365386e-02
#    3.34994425e-01 -6.72610759e-02  1.69199005e-01  3.75455627e-02
#    1.13179675e-01  3.91052335e-02  4.36995633e-02  2.97631441e-01
#    5.58862378e-01  2.70617022e-01 -6.26050705e-01 -9.00491778e-01
#    1.05027400e+00 -6.23640029e-02  6.79064749e-01  0.00000000e+00
#    0.00000000e+00]]

# %% [markdown]
# ### Make coefficients easier to read

# %%
np.set_printoptions(formatter={'float': lambda x: "{0:0.3f}".format(x)})

# %%
coef_cols = pd.DataFrame(train_coef, columns=['Coef'])
coef_cols['Source'] = columns
coef_cols.sort_values(by=['Coef'], axis=0, ascending=False, inplace=True)
print(coef_cols)
# Out:
#         Coef                                             Source
# 24  1.050274                                  Cat_Entertainment
# 26  0.679065                                     Cat_Fancy Food
# 20  0.558862                          Neighborhood_West Village
# 8   0.427931                    Neighborhood_Financial District
# 12  0.334994                           Neighborhood_Murray Hill
# 3   0.300759                                       City_Toronto
# 19  0.297631                       Neighborhood_Upper West Side
# 21  0.270617                             Neighborhood_Yorkville
# 14  0.169199              Neighborhood_Richmond, Adelaide, King
# 6   0.139491        Neighborhood_Commerce Court, Victoria Hotel
# 16  0.113180                        Neighborhood_St. James Town
# 7   0.085241                          Neighborhood_East Village
# 2   0.077508                                             Rating
# 4   0.073936                    Neighborhood_Central Bay Street
# 18  0.043700  Neighborhood_Toronto Dominion Centre, Design E...
# 9   0.040106  Neighborhood_First Canadian Place, Underground...
# 17  0.039105  Neighborhood_Stn A PO Boxes, 25 The Esplanade,...
# 15  0.037546                            Neighborhood_South Side
# 0   0.000675                                          TipsCount
# 1   0.000241                                         LikesCount
# 27  0.000000                                       Cat_FunStore
# 28  0.000000                                     Cat_Recreation
# 5  -0.001137                  Neighborhood_Church and Wellesley
# 11 -0.028137  Neighborhood_Harbourfront East, Union Station,...
# 25 -0.062364                                    Cat_Ethnic Food
# 13 -0.067261                            Neighborhood_North Side
# 10 -0.288684              Neighborhood_Garden District, Ryerson
# 22 -0.626051                                      Cat_CheapMeal
# 23 -0.900492                                  Cat_CoffeeDessert

# %%
arr2 = np.sort(regr.coef_, axis = -1)        
print(arr2)
# Out:
# [[-0.900 -0.626 -0.289 -0.067 -0.062 -0.028 -0.001 0.000 0.000 0.000
#   0.001 0.038 0.039 0.040 0.044 0.074 0.078 0.085 0.113 0.139 0.169 0.271
#   0.298 0.301 0.335 0.428 0.559 0.679 1.050]]

# %%
y_hat= regr.predict(no_price_df[columns])

# %% [markdown]
# ### I want to add the predictions to the no price data

# %%
no_price_df['PriceTier'] = y_hat
# Out:
# <ipython-input-50-be024e5880c6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   no_price_df['PriceTier'] = y_hat

# %%
price_filt = no_price_df['PriceTier'] > 3

no_price_df[price_filt].sort_values(by=['PriceTier'], ascending=False).head(25)
# Out:
#       TipsCount  LikesCount  Rating  PriceTier  City_Toronto  \
# 154         273        2191     8.7   3.929128             1
# 155         273        2191     8.7   3.924534             1
# 1836        300        2217     8.7   3.881795             1
# 153         273        2191     8.7   3.857292             1
# 1825        275        1439     8.8   3.684930             1
# 1859        177         844     9.2   3.568563             0
# 1398         37         140     8.8   3.497028             0
# 343          79         407     8.7   3.463449             1
# 319          42         318     8.7   3.446701             1
# 331          44         222     8.6   3.417135             1
# 1389          9          32     8.2   3.405558             0
# 1388          8          17     8.1   3.393512             0
# 342          79         407     8.7   3.367658             1
# 345          79         407     8.7   3.364065             1
# 344          79         407     8.7   3.363064             1
# 701          44         164     8.8   3.362622             1
# 1813         57         470     9.1   3.327175             1
# 320          42         318     8.7   3.321202             1
# 321          42         318     8.7   3.317609             1
# 435          33          56     8.0   3.293438             1
# 332          44         222     8.6   3.288042             1
# 1804          4          12     7.8   3.277448             1
# 2357        300         638     9.5   3.222892             0
# 104          44         264     7.5   3.216512             1
# 105          44         264     7.5   3.211917             1
#
#       Neighborhood_Central Bay Street  Neighborhood_Church and Wellesley  \
# 154                                 0                                  0
# 155                                 0                                  0
# 1836                                0                                  0
# 153                                 0                                  0
# 1825                                0                                  0
# 1859                                0                                  0
# 1398                                0                                  0
# 343                                 0                                  0
# 319                                 0                                  0
# 331                                 0                                  0
# 1389                                0                                  0
# 1388                                0                                  0
# 342                                 0                                  0
# 345                                 0                                  0
# 344                                 0                                  0
# 701                                 0                                  0
# 1813                                0                                  0
# 320                                 0                                  0
# 321                                 0                                  0
# 435                                 0                                  0
# 332                                 0                                  0
# 1804                                0                                  0
# 2357                                0                                  0
# 104                                 0                                  0
# 105                                 0                                  0
#
#       Neighborhood_Commerce Court, Victoria Hotel  Neighborhood_East Village  \
# 154                                             0                          0
# 155                                             0                          0
# 1836                                            0                          0
# 153                                             0                          0
# 1825                                            0                          0
# 1859                                            0                          0
# 1398                                            0                          0
# 343                                             1                          0
# 319                                             0                          0
# 331                                             0                          0
# 1389                                            0                          0
